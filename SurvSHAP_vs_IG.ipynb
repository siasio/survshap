# %% [markdown]
# # SurvSHAP vs DeepLift vs Integrated Gradients
# ### J. Krajewski, S. Frejlak, M. Wojtala

# %% [markdown]
# ### Notebook description

# %% [markdown]
# This notebook contains experiments aiming at establishing the quality of gradient-based methods for deep survival models and comparing their explanations with those prvovided by SurvSHAP.

# %% [markdown]
# #### Data

# %% [markdown]
# We take datasets containing time-dependent data from the original SurvSHAP repository. The first dataset on which we run experiments, `exp1_data_complex.csv`,  is artificial. Dependence of the `event` variable on explanatory variable `x1` changes through time. Dependence on the variables `x2`, `x3` and `x4` doesn't change through time. The last explanatory variable `x5` is just noise, and the explained variable doesn't depend on it. The dataset contains 1000 examples.
#
# The second dataset on which we run experiments, `exp3_heart_failure_dataset.csv`, contains medical data. There are eleven explanatory variables and the survival model is trained to predict `DEATH_EVENT` after a given period of time passes.

# %% [markdown]
# #### Deep survival model

# %% [markdown]
# As a deep survival model, we use `DeepHitSingle` from the `pycox` library. It's an implementation of the DeepHit method for a single event, as opposed to competing risks. The method is described in this paper: https://ojs.aaai.org/index.php/AAAI/article/view/11842

# %% [markdown]
# #### Explanation methods

# %% [markdown]
# As a gradient-based explanation method, we use `IntegratedGradients` from the `captum` library. It's an implementation of the method described in this paper: https://arxiv.org/abs/1703.01365
#
# We compare the attributions obtained by Integrated Gradient with SurvSHAP attributions. SurvSHAP is a model-agnostic explanation method designed specifically for survival models. It is described in this paper: https://arxiv.org/abs/2208.11080

# %% [markdown]
# #### Used metrics

# %% [markdown]
# We measure the accuracy of Integrated Gradients attributions using Brier score. We further use metrics of Average Sensitivity and Faithfulness Correlation, taking their implemations from the `quantus` library. Both of these metrics are defined in this paper: https://arxiv.org/abs/2005.00631

# %% [markdown]
# ### Imports

# %%
# This code is useful if you want to make changes in any of the imported libraries, e.g. to solve compatibility issues.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip3 install torchtuples
# !pip3 install pycox

import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
from scipy.integrate import trapezoid
from typing import List
from datetime import datetime
import os
import matplotlib.pyplot as plt

# For preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
from sksurv.functions import StepFunction

import torch # For building the networks
import torchtuples as tt # Some useful functions

from pycox.models import DeepHitSingle

from survshap import SurvivalModelExplainer, ModelSurvSHAP, PredictSurvSHAP
from captum.attr import (
    GradientShap,
    DeepLift,
    DeepLiftShap,
    IntegratedGradients,
)

import quantus

from pycox.evaluation import EvalSurv
import plotly.graph_objs as go
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "jpeg"

# os.environ["CUDA_VISIBLE_DEVICES"]=""

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Requirement already satisfied: torchtuples in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (0.2.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from torchtuples) (1.4.4)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from torchtuples) (1.23.4)
# Requirement already satisfied: matplotlib>=3.0.3 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from torchtuples) (3.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pandas>=0.24.2->torchtuples) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->torchtuples) (1.16.0)
# Requirement already satisfied: pycox in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: scikit-learn>=0.21.2 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (1.1.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (3.7.0)
# Requirement already satisfied: numba>=0.44 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (0.56.4)
# Requirement already satisfied: requests>=2.22.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (2.28.1)
# Requirement already satisfied: py7zr>=0.11.3 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (0.20.2)
# Requirement already satisfied: feather-format>=0.4.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (0.4.1)
# Requirement already satisfied: torchtuples>=0.2.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pycox) (0.2.2)
# Requirement already satisfied: pyarrow>=0.4.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from feather-format>=0.4.0->pycox) (8.0.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from h5py>=2.9.0->pycox) (1.23.4)
# Requirement already satisfied: setuptools in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from numba>=0.44->pycox) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from numba>=0.44->pycox) (0.39.1)
# Requirement already satisfied: texttable in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (1.6.7)
# Requirement already satisfied: pyzstd>=0.14.4 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (0.15.3)
# Requirement already satisfied: pybcj>=0.6.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (1.0.1)
# Requirement already satisfied: brotli>=1.0.9 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (1.0.9)
# Requirement already satisfied: inflate64>=0.3.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (0.3.1)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (1.0.0)
# Requirement already satisfied: psutil in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (5.9.0)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (3.16.0)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from py7zr>=0.11.3->pycox) (0.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from requests>=2.22.0->pycox) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from requests>=2.22.0->pycox) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from requests>=2.22.0->pycox) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from requests>=2.22.0->pycox) (3.4)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->pycox) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->pycox) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->pycox) (1.9.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from torchtuples>=0.2.0->pycox) (1.4.4)
# Requirement already satisfied: matplotlib>=3.0.3 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from torchtuples>=0.2.0->pycox) (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from pandas>=0.24.2->torchtuples>=0.2.0->pycox) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\stanislawfrejlak\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->torchtuples>=0.2.0->pycox) (1.16.0)

# %% [markdown]
# ### Helper classes and functions

# %% [markdown]
# #### Data preprocessing

# %%
class ColumnNotPresentError(Exception):
    def __init__(self, ke, column_name_parameter, column_names):
        self.message = f"'{ke.__str__}' not present in dataframe columns. Please, specify the correct column name(s) as parameter(s) {column_name_parameter}. Available options: {', '.join(list(column_names))}"
        super().__init__(self.message)


def train_val_test_split(dataframe_raw, verbose=True, time_column='time'):
    dataframe_test = dataframe_raw.sample(frac=0.2, random_state=8)
    dataframe_train = dataframe_raw.drop(dataframe_test.index)
    dataframe_val = dataframe_train.sample(frac=0.2, random_state=8)
    dataframe_train = dataframe_train.drop(dataframe_val.index)
    if verbose:
        print(dataframe_raw.head())
        try:
            print(f"Min time: {dataframe_raw[time_column].min():.4g} Max time: {dataframe_raw[time_column].max():.4g} Average time: {dataframe_raw[time_column].mean():.4g}")
        except KeyError as ke:
            raise ColumnNotPresentError(ke, 'time_column', dataframe_raw.columns)
    return dataframe_train, dataframe_test, dataframe_val

def standardize_mapper(to_standardize, to_leave):
    standardize = [([col], StandardScaler()) for col in to_standardize]
    leave = [(col, None) for col in to_leave]

    return DataFrameMapper(leave + standardize)

# %%
def prepare_x_y(dataframe_split: List[pd.DataFrame], to_standardize, to_leave, num_durations, time_column='time',
                event_column='event'):
    """Provide a dataframe with the training set as the first one in the list dataframe_split"""
    x_mapper = standardize_mapper(to_standardize, to_leave)
    label_transform = DeepHitSingle.label_transform(num_durations)
    df_first = dataframe_split[0]

    try:
        get_target = lambda df: (df[time_column].values, df[event_column].values)

        x_list = [x_mapper.fit_transform(df_first).astype('float32')]
        y_list = [label_transform.fit_transform(*get_target(df_first))]
        for df_next in dataframe_split[1:]:
            x_list.append(x_mapper.transform(df_next).astype('float32'))
            y_list.append(label_transform.transform(*get_target(df_next)))
    except KeyError as ke:
        raise ColumnNotPresentError(ke, 'time_column, event_column', df_first.columns)
    return zip(x_list, y_list), label_transform

# %% [markdown]
# ### Helper classes for unifying the worlds of SurvSHAP and cpatum

# %%
class DeepHitSingle_(DeepHitSingle):
    """Extension of the DeepHitSingle class from pycox to make it compatible with SurvShap and IG"""

    def predict_survival_function(self, X):
        X = torch.tensor(np.asarray(X), dtype=torch.float32).to(DEVICE)

        surv_df = self.predict_surv_df(X, batch_size=128).astype("float32")
        event_times_ = surv_df.index.values
        sf_values = surv_df.T.values

        return np.array([StepFunction(event_times_, values) for values in sf_values])

    def plot_survival_function(self, observation_number: int):
        new_observation = pd.DataFrame(
            np.atleast_2d(self.x_val[observation_number]),
            columns=[f"var_{i}" for i in range(self.x_val.shape[1])],
        )

        return px.line(
            x=self.predict_survival_function(new_observation)[0].x,
            y=self.predict_survival_function(new_observation)[0].y,
        )

    # Should be not necessary in our case
    def predict_cumulative_hazard_function(self, X):
        X = torch.tensor(np.asarray(X), dtype=torch.float32).to(DEVICE)

        pmf = self.predict_pmf(X, numpy=True, to_cpu=True).astype("float32")
        # event_times_ = list(range(pmf.shape[1]))
        surv_df = self.predict_surv_df(X, batch_size=128).astype("float32")
        event_times_ = surv_df.index.values

        return np.array([StepFunction(event_times_, p) for p in pmf])

    def fit(self, *args, **kwargs):
        self.x_val, self.y_val = kwargs["val_data"]
        return super().fit(*args, **kwargs)

# %% [markdown]
# #### Computation and visualization of attributions and metrics

# %%
def compute_attributions(model, inputs, outputs, num_durations, all_input, columns):
    num_examples = inputs.shape[0]
    num_features = inputs.shape[1]
    aggregated_attributions = np.empty([num_examples, num_durations, num_features])
    survshap_attributions = np.empty([num_examples, num_durations, num_features])

    inputs_torch = torch.tensor(inputs).cuda()
    all_input = torch.tensor(all_input).cuda()
    baseline = torch.min(all_input, dim=0, keepdim=True)[0].expand([num_examples, num_features])
    # baseline = torch.zeros_like(inputs_torch)

    survshap = PredictSurvSHAP()
    # convert data to SurvSHAP format
    x_val_surv = pd.DataFrame(
        inputs, columns=columns
    )
    y_val_surv= [(bool(event), time) for time, event in zip(outputs[0], outputs[1])]
    y_val_surv = np.array(
        y_val_surv, np.dtype([("event", "?"), ("duration", "<f8")])
    )

    survshap_explainer = SurvivalModelExplainer(model, data=x_val_surv, y=y_val_surv)
    for obs in tqdm(range(num_examples)):
        new_observation = pd.DataFrame(
            np.atleast_2d(inputs[obs]),
            columns=columns,
        )
        survshap.fit(
            survshap_explainer,
            new_observation=new_observation,
            timestamps=labtrans.cuts
        )
        # We want to see if the variables contribute positively or negatively to the model predictions.
        # For this purpose we multiply the SurvSHAP values by the difference between inputs and baselines.
        # This is also how it is done in Integrated Gradients to obtain global attributions.
        inputs_baseline_diff = np.broadcast_to(np.expand_dims(inputs[obs] - baseline.cpu().numpy()[obs], axis=0), [num_durations, num_features])
        survshap_attributions[obs, :, :] = survshap.result.iloc[:, 5:].values.squeeze().transpose() * inputs_baseline_diff

    ig = IntegratedGradients(model.net, multiply_by_inputs=True)
    for t in range(num_durations):
        aggregated_attributions[:, t, :] = ig.attribute(inputs_torch, baselines=baseline, target=t).detach().cpu().numpy()
        # According to my understanding, we shouldn't count the cumulative sum:
        # if t > 0:
        #     aggregated_attributions[:, t, :] = aggregated_attributions[:, t, :] + aggregated_attributions[:, t-1, :]
    actual_data_attributions = aggregated_attributions[np.arange(num_examples), outputs[0]]
    actual_survshap_attributions = aggregated_attributions[np.arange(num_examples), outputs[0]]

    return  aggregated_attributions, actual_data_attributions, survshap_attributions, actual_survshap_attributions


def compute_metrics(model, input_np, output_np, actual_data_attributions, metrics):
    if len(output_np) == 2:
        output_np = output_np[1]
    output_np = output_np.astype(np.int64)
    metric_scores = []
    for metric in metrics:
        scores = metric(
            model=model.net,
            channel_first=True,
            x_batch=input_np,
            y_batch=output_np,
            a_batch=actual_data_attributions,
            device=DEVICE,
            explain_func=quantus.explain,
            explain_func_kwargs={"method": "IntegratedGradients"}
        )
        metric_scores.append(np.array(scores).squeeze())

    return metric_scores

# %%
# define colors as a list
colors = px.colors.qualitative.Plotly

# convert plotly hex colors to rgba to enable transparency adjustments
def hex_rgba(hex, transparency):
    col_hex = hex.lstrip('#')
    col_rgb = list(int(col_hex[i:i+2], 16) for i in (0, 2, 4))
    col_rgb.extend([transparency])
    areacol = tuple(col_rgb)
    return areacol

rgba = [hex_rgba(c, transparency=0.2) for c in colors]
colCycle = ['rgba'+str(elem) for elem in rgba]

# Make sure the colors run in cycles if there are more lines than colors
def next_col(cols):
    while True:
        for col in cols:
            yield col

line_color = next_col(colCycle)

# %%
class PlotCreator:
    save_dir = None

    def __init__(self, save_dir=None):
        if save_dir:
            now = datetime.now()
            dt_string = now.strftime("_%Y-%m-%d_%H-%M-%S")
            self.save_dir = save_dir + dt_string
            os.makedirs(self.save_dir)

    def create_plots(self, arrs, variables, x, example_nums, save=True, show=True, desc="Attributions", xaxis_title="Time cuts by label transform", yaxis_title="Attribution * (input - baseline)", legend_title="Variable"):
        for arr, variable in zip(arrs, variables):
            self.mean_std_figure(arr, variable, x, save=save, show=show, desc=desc, xaxis_title=xaxis_title, yaxis_title=yaxis_title, legend_title=legend_title)
        self.figure_per_var(arrs, variables, x, save=save, show=show, desc=desc, xaxis_title=xaxis_title, yaxis_title=yaxis_title, legend_title=legend_title)
        for example_num in example_nums:
            self.figure_per_var(arrs, variables, x, example_num=example_num, save=save, show=show, desc=desc, xaxis_title=xaxis_title, yaxis_title=yaxis_title, legend_title=legend_title)


    def mean_std_figure(self, arr, variable, x, y_means=None, y_stds=None, save=True, show=True, desc="Attributions", xaxis_title="Time cuts by label transform", yaxis_title="Attribution * (input - baseline)", legend_title="Variable"):
        if not self.save_dir:
            save = False

        if y_means is None and y_stds is None:
            y_means = np.apply_along_axis(lambda a: a.mean(), axis=0, arr=arr)
            y_stds = np.apply_along_axis(lambda a: a.std(), axis=0, arr=arr)
        y_means[np.where(np.isnan(y_means))] = np.nanmean(y_means)
        y_stds[np.where(np.isnan(y_stds))] = np.nanmean(y_stds)

        y_means = y_means.tolist()
        y_means.append(y_means[-1])

        y_stds = y_stds.tolist()
        y_stds.append(y_stds[-1])
        y_lows = [y_m - y_s for y_m, y_s in zip(y_means, y_stds)]
        y_ups = [y_m + y_s for y_m, y_s in zip(y_means, y_stds)]

        fig = go.Figure()
        new_col = next(line_color)
        title = f'{desc} over whole dataset'

        # standard deviation area
        fig.add_traces(go.Scatter(x=x,
                                  y=y_lows,
                                  fillcolor=new_col,
                                  line=dict(color='rgba(255,255,255,0)', shape='hv'),
                                  showlegend=False,
                                  name=variable)
                       )

        fig.add_traces(go.Scatter(x=x,
                                  y=y_ups,
                                  fill='tonexty',
                                  fillcolor=new_col,
                                  line=dict(color='rgba(255,255,255,0)', shape='hv'),
                                  showlegend=False,
                                  name=variable)
                       )

        # line trace
        fig.add_traces(go.Scatter(x=x,
                                  y=y_means,
                                  line=dict(color=new_col, width=3.5, shape='hv'),
                                  mode='lines',
                                  name=variable)
                       )

        # set x-axis
        fig.update_layout(xaxis=dict(range=[0,num_durations]),
                          title=title,
                          xaxis_title=xaxis_title,
                          yaxis_title=yaxis_title,
                          legend_title=legend_title,
                          )
        if show:
            fig.show()
        if save:
            filename = f'{variable}-{"_".join(title.split())}.png'
            fig.write_image(os.path.join(self.save_dir, filename))

    def figure_per_var(self, arrs, variables, x, example_num=None, save=True, show=True, desc="Attributions", xaxis_title="Time cuts by label transform", yaxis_title="Attribution * (input - baseline)", legend_title="Variable"):
        """Plots values in a specified row of an array if example_num is provided.
        Otherwise, plots a mean over all examples."""

        if not self.save_dir:
            save = False

        fig = go.Figure()
        title = f'{desc} for example {example_num}' if example_num is not None else f'{desc} over whole dataset'
        for arr, var in zip(arrs, variables):
            y_to_plot = arr[example_num] if example_num is not None else np.apply_along_axis(lambda a: a.mean(), axis=0, arr=arr)
            y_to_plot[np.where(np.isnan(y_to_plot))] = np.nanmean(y_to_plot)
            y_to_plot = y_to_plot.tolist()
            y_to_plot.append(y_to_plot[-1])
            new_col = next(line_color)
            fig.add_traces(go.Scatter(x=x,
                                      y=y_to_plot,
                                      line=dict(color=new_col, width=3.5, shape='hv'),
                                      mode='lines',
                                      name=var)
                           )
        fig.update_layout(xaxis=dict(range=[0,num_durations]),
                          title=title,
                          xaxis_title=xaxis_title,
                          yaxis_title=yaxis_title,
                          legend_title=legend_title,
                          )
        if show:
            fig.show()
        if save:
            filename = f'{"_".join(title.split())}.png'
            fig.write_image(os.path.join(self.save_dir, filename))

    @staticmethod
    def mean_std_per_time(arr, times, all_times):
        df = pd.DataFrame({'value': arr, 'time': times})
        means = np.empty([all_times])
        stds = np.empty([all_times])
        for time in range(all_times):
            means[time] = df.value[df.time == time].mean()
            stds[time] = df.value[df.time == time].std()
        return means, stds

# %% [markdown]
# #### Metrics definitions

# %%
avg_sensitivity = quantus.AvgSensitivity(nr_samples=50,
                                         lower_bound=0.2,
                                         norm_numerator=quantus.norm_func.fro_norm,
                                         norm_denominator=quantus.norm_func.fro_norm,
                                         perturb_func=quantus.perturb_func.uniform_noise,
                                         similarity_func=quantus.similarity_func.difference,
                                         disable_warnings=True,
                                         aggregate_func=np.mean,
                                         upper_bound=None
                                         )

faithfulness_corr = quantus.FaithfulnessCorrelation(subset_size=1,  # 'subset_size' must be smaller than input size
                                                    similarity_func=(lambda a, b: quantus.similarity_func.difference(np.array(a),
                                                                                                                     np.array(b))),
                                                    perturb_func=quantus.perturb_func.uniform_noise)
used_metrics = [avg_sensitivity, faithfulness_corr]
metrics_names = ['Avg Sensitivity', 'Faithfulness Corr']
# Out:
# Warnings and information:
#  (1) The Faithfulness Correlation metric is likely to be sensitive to the choice of baseline value 'perturb_baseline', size of subset |S| 'subset_size' and the number of runs (for each input and explanation pair) 'nr_runs'.
#  (2) If attributions are normalised or their absolute values are taken it may destroy or skew information in the explanation and as a result, affect the overall evaluation outcome.
#  (3) Make sure to validate the choices for hyperparameters of the metric (by calling .get_params of the metric instance).
#  (4) For further information, see original publication: Bhatt, Umang, Adrian Weller, and José MF Moura. 'Evaluating and aggregating feature-based model explanations.' arXiv preprint arXiv:2005.00631 (2020).
#  (5) To disable these warnings set 'disable_warnings' = True when initialising the metric.

# %% [markdown]
# ### Experiment 1: Artificial data

# %%
df_raw = pd.read_csv('data/exp1_data_complex.csv')

df_train, df_val, df_test = train_val_test_split(df_raw)
# Out:
#    x1  x2         x3         x4        x5       time  event
# 0   0   0  12.559994   8.810540 -0.335024   1.371523      0
# 1   1   1   7.848031  24.935806 -0.815996   1.031760      0
# 2   0   0   9.851197  20.999098 -0.107522  13.387439      0
# 3   1   0  10.398557  12.633733 -1.129195   7.879721      0
# 4   0   1   7.082080  20.895630  0.605936   1.939003      1
# Min time: 0.0126 Max time: 14.68 Average time: 5.425

# %%
cols_standardize = ['x3', 'x4', 'x5']
cols_leave = ['x1', 'x2']
all_variables = ['x1', 'x2', 'x3', 'x4', 'x5']
num_durations = 40

(train, val, test, raw), labtrans = prepare_x_y([df_train, df_val, df_test, df_raw], cols_standardize, cols_leave, num_durations)
x_train, y_train = train
x_val, y_val = val
x_test, y_test = test
x_raw, y_raw = raw

# %%
in_features = x_train.shape[1]
num_nodes = [5]
out_features = labtrans.out_features
batch_norm = True
dropout = 0.0
lr = 0.00001

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm, dropout)
model = DeepHitSingle_(net, tt.optim.Adam(lr), duration_index=labtrans.cuts, device=DEVICE)

# %%
batch_size = 64
epochs = 10000
callbacks = []  # tt.cb.EarlyStopping(patience=50)

# with open('', 'rb') as handle:
#     model = pickle.load(handle)

log = model.fit(x_train, y_train, batch_size, epochs, callbacks, val_data=val)
_ = log.plot()
# Out:
# 0:	[0s / 0s],		train_loss: 1.0314,	val_loss: 0.8714
# 1:	[0s / 0s],		train_loss: 1.0270,	val_loss: 0.9023
# 2:	[0s / 0s],		train_loss: 1.0354,	val_loss: 0.9268
# 3:	[0s / 0s],		train_loss: 1.0316,	val_loss: 0.9391
# 4:	[0s / 0s],		train_loss: 1.0332,	val_loss: 0.9445
# 5:	[0s / 0s],		train_loss: 1.0328,	val_loss: 0.9483
# 6:	[0s / 0s],		train_loss: 1.0345,	val_loss: 0.9466
# 7:	[0s / 0s],		train_loss: 1.0259,	val_loss: 0.9491
# 8:	[0s / 0s],		train_loss: 1.0271,	val_loss: 0.9511
# 9:	[0s / 0s],		train_loss: 1.0340,	val_loss: 0.9488
# 10:	[0s / 0s],		train_loss: 1.0252,	val_loss: 0.9514
# 11:	[0s / 0s],		train_loss: 1.0354,	val_loss: 0.9488
# 12:	[0s / 0s],		train_loss: 1.0363,	val_loss: 0.9496
# 13:	[0s / 0s],		train_loss: 1.0311,	val_loss: 0.9460
# 14:	[0s / 0s],		train_loss: 1.0209,	val_loss: 0.9481
# 15:	[0s / 0s],		train_loss: 1.0268,	val_loss: 0.9510
# 16:	[0s / 0s],		train_loss: 1.0263,	val_loss: 0.9495
# 17:	[0s / 0s],		train_loss: 1.0272,	val_loss: 0.9478
# 18:	[0s / 0s],		train_loss: 1.0281,	val_loss: 0.9478
# 19:	[0s / 0s],		train_loss: 1.0274,	val_loss: 0.9482
# 20:	[0s / 1s],		train_loss: 1.0251,	val_loss: 0.9486
# 21:	[0s / 1s],		train_loss: 1.0148,	val_loss: 0.9479
# 22:	[0s / 1s],		train_loss: 1.0315,	val_loss: 0.9448
# 23:	[0s / 1s],		train_loss: 1.0273,	val_loss: 0.9441
# 24:	[0s / 1s],		train_loss: 1.0191,	val_loss: 0.9444
# 25:	[0s / 1s],		train_loss: 1.0120,	val_loss: 0.9456
# 26:	[0s / 1s],		train_loss: 1.0272,	val_loss: 0.9451
# 27:	[0s / 1s],		train_loss: 1.0188,	val_loss: 0.9452
# 28:	[0s / 1s],		train_loss: 1.0295,	val_loss: 0.9456
# 29:	[0s / 1s],		train_loss: 1.0168,	val_loss: 0.9438
# 30:	[0s / 1s],		train_loss: 1.0202,	val_loss: 0.9424
# 31:	[0s / 1s],		train_loss: 1.0200,	val_loss: 0.9416
# 32:	[0s / 1s],		train_loss: 1.0174,	val_loss: 0.9441
# 33:	[0s / 1s],		train_loss: 1.0152,	val_loss: 0.9425
# 34:	[0s / 1s],		train_loss: 1.0173,	val_loss: 0.9433
# 35:	[0s / 1s],		train_loss: 1.0168,	val_loss: 0.9420
# 36:	[0s / 1s],		train_loss: 1.0187,	val_loss: 0.9405
# 37:	[0s / 1s],		train_loss: 1.0159,	val_loss: 0.9419
# 38:	[0s / 1s],		train_loss: 1.0137,	val_loss: 0.9391
# 39:	[0s / 1s],		train_loss: 1.0132,	val_loss: 0.9378
# 40:	[0s / 1s],		train_loss: 1.0193,	val_loss: 0.9398
# 41:	[0s / 1s],		train_loss: 1.0104,	val_loss: 0.9422
# 42:	[0s / 1s],		train_loss: 1.0051,	val_loss: 0.9409
# 43:	[0s / 2s],		train_loss: 1.0158,	val_loss: 0.9381
# 44:	[0s / 2s],		train_loss: 1.0089,	val_loss: 0.9403
# 45:	[0s / 2s],		train_loss: 1.0037,	val_loss: 0.9409
# 46:	[0s / 2s],		train_loss: 1.0126,	val_loss: 0.9397
# 47:	[0s / 2s],		train_loss: 1.0176,	val_loss: 0.9369
# 48:	[0s / 2s],		train_loss: 1.0107,	val_loss: 0.9370
# 49:	[0s / 2s],		train_loss: 1.0132,	val_loss: 0.9355
# 50:	[0s / 2s],		train_loss: 1.0113,	val_loss: 0.9377
# 51:	[0s / 2s],		train_loss: 1.0123,	val_loss: 0.9364
# 52:	[0s / 2s],		train_loss: 1.0094,	val_loss: 0.9366
# 53:	[0s / 2s],		train_loss: 1.0106,	val_loss: 0.9388
# 54:	[0s / 2s],		train_loss: 1.0068,	val_loss: 0.9381
# 55:	[0s / 2s],		train_loss: 1.0027,	val_loss: 0.9368
# 56:	[0s / 2s],		train_loss: 1.0125,	val_loss: 0.9347
# 57:	[0s / 2s],		train_loss: 1.0172,	val_loss: 0.9385
# 58:	[0s / 2s],		train_loss: 1.0144,	val_loss: 0.9344
# 59:	[0s / 2s],		train_loss: 1.0010,	val_loss: 0.9360
# 60:	[0s / 2s],		train_loss: 1.0146,	val_loss: 0.9327
# 61:	[0s / 2s],		train_loss: 1.0080,	val_loss: 0.9335
# 62:	[0s / 2s],		train_loss: 1.0009,	val_loss: 0.9325
# 63:	[0s / 2s],		train_loss: 1.0028,	val_loss: 0.9337
# 64:	[0s / 3s],		train_loss: 1.0050,	val_loss: 0.9331
# 65:	[0s / 3s],		train_loss: 1.0013,	val_loss: 0.9340
# 66:	[0s / 3s],		train_loss: 1.0013,	val_loss: 0.9339
# 67:	[0s / 3s],		train_loss: 0.9966,	val_loss: 0.9324
# 68:	[0s / 3s],		train_loss: 1.0023,	val_loss: 0.9324
# 69:	[0s / 3s],		train_loss: 1.0065,	val_loss: 0.9331
# 70:	[0s / 3s],		train_loss: 1.0029,	val_loss: 0.9318
# 71:	[0s / 3s],		train_loss: 1.0128,	val_loss: 0.9322
# 72:	[0s / 3s],		train_loss: 1.0041,	val_loss: 0.9325
# 73:	[0s / 3s],		train_loss: 0.9985,	val_loss: 0.9352
# 74:	[0s / 3s],		train_loss: 1.0007,	val_loss: 0.9333
# 75:	[0s / 3s],		train_loss: 1.0026,	val_loss: 0.9315
# 76:	[0s / 3s],		train_loss: 0.9960,	val_loss: 0.9280
# 77:	[0s / 3s],		train_loss: 1.0015,	val_loss: 0.9288
# 78:	[0s / 3s],		train_loss: 0.9959,	val_loss: 0.9304
# 79:	[0s / 3s],		train_loss: 1.0000,	val_loss: 0.9286
# 80:	[0s / 3s],		train_loss: 1.0000,	val_loss: 0.9310
# 81:	[0s / 3s],		train_loss: 0.9932,	val_loss: 0.9286
# 82:	[0s / 3s],		train_loss: 0.9961,	val_loss: 0.9294
# 83:	[0s / 3s],		train_loss: 0.9912,	val_loss: 0.9304
# 84:	[0s / 3s],		train_loss: 0.9918,	val_loss: 0.9274
# 85:	[0s / 3s],		train_loss: 0.9997,	val_loss: 0.9292
# 86:	[0s / 3s],		train_loss: 0.9955,	val_loss: 0.9280
# 87:	[0s / 4s],		train_loss: 0.9992,	val_loss: 0.9290
# 88:	[0s / 4s],		train_loss: 0.9916,	val_loss: 0.9279
# 89:	[0s / 4s],		train_loss: 0.9999,	val_loss: 0.9269
# 90:	[0s / 4s],		train_loss: 0.9975,	val_loss: 0.9266
# 91:	[0s / 4s],		train_loss: 0.9963,	val_loss: 0.9263
# 92:	[0s / 4s],		train_loss: 1.0004,	val_loss: 0.9275
# 93:	[0s / 4s],		train_loss: 0.9973,	val_loss: 0.9263
# 94:	[0s / 4s],		train_loss: 0.9911,	val_loss: 0.9240
# 95:	[0s / 4s],		train_loss: 0.9854,	val_loss: 0.9248
# 96:	[0s / 4s],		train_loss: 0.9971,	val_loss: 0.9241
# 97:	[0s / 4s],		train_loss: 0.9962,	val_loss: 0.9259
# 98:	[0s / 4s],		train_loss: 0.9979,	val_loss: 0.9241
# 99:	[0s / 4s],		train_loss: 0.9864,	val_loss: 0.9256
# 100:	[0s / 4s],		train_loss: 1.0008,	val_loss: 0.9278
# 101:	[0s / 4s],		train_loss: 0.9877,	val_loss: 0.9256
# 102:	[0s / 4s],		train_loss: 0.9946,	val_loss: 0.9250
# 103:	[0s / 4s],		train_loss: 0.9879,	val_loss: 0.9277
# 104:	[0s / 4s],		train_loss: 0.9886,	val_loss: 0.9264
# 105:	[0s / 4s],		train_loss: 0.9878,	val_loss: 0.9228
# 106:	[0s / 4s],		train_loss: 0.9877,	val_loss: 0.9219
# 107:	[0s / 4s],		train_loss: 0.9842,	val_loss: 0.9224
# 108:	[0s / 4s],		train_loss: 0.9838,	val_loss: 0.9242
# 109:	[0s / 5s],		train_loss: 0.9900,	val_loss: 0.9229
# 110:	[0s / 5s],		train_loss: 0.9915,	val_loss: 0.9206
# 111:	[0s / 5s],		train_loss: 0.9928,	val_loss: 0.9210
# 112:	[0s / 5s],		train_loss: 0.9832,	val_loss: 0.9220
# 113:	[0s / 5s],		train_loss: 0.9903,	val_loss: 0.9248
# 114:	[0s / 5s],		train_loss: 0.9878,	val_loss: 0.9231
# 115:	[0s / 5s],		train_loss: 0.9881,	val_loss: 0.9230
# 116:	[0s / 5s],		train_loss: 0.9874,	val_loss: 0.9237
# 117:	[0s / 5s],		train_loss: 0.9931,	val_loss: 0.9194
# 118:	[0s / 5s],		train_loss: 0.9845,	val_loss: 0.9189
# 119:	[0s / 5s],		train_loss: 0.9851,	val_loss: 0.9206
# 120:	[0s / 5s],		train_loss: 0.9888,	val_loss: 0.9219
# 121:	[0s / 5s],		train_loss: 0.9776,	val_loss: 0.9199
# 122:	[0s / 5s],		train_loss: 0.9788,	val_loss: 0.9189
# 123:	[0s / 5s],		train_loss: 0.9854,	val_loss: 0.9183
# 124:	[0s / 5s],		train_loss: 0.9870,	val_loss: 0.9184
# 125:	[0s / 5s],		train_loss: 0.9859,	val_loss: 0.9168
# 126:	[0s / 5s],		train_loss: 0.9813,	val_loss: 0.9177
# 127:	[0s / 5s],		train_loss: 0.9823,	val_loss: 0.9178
# 128:	[0s / 5s],		train_loss: 0.9835,	val_loss: 0.9167
# 129:	[0s / 5s],		train_loss: 0.9841,	val_loss: 0.9169
# 130:	[0s / 6s],		train_loss: 0.9834,	val_loss: 0.9174
# 131:	[0s / 6s],		train_loss: 0.9835,	val_loss: 0.9163
# 132:	[0s / 6s],		train_loss: 0.9876,	val_loss: 0.9180
# 133:	[0s / 6s],		train_loss: 0.9839,	val_loss: 0.9153
# 134:	[0s / 6s],		train_loss: 0.9843,	val_loss: 0.9172
# 135:	[0s / 6s],		train_loss: 0.9785,	val_loss: 0.9180
# 136:	[0s / 6s],		train_loss: 0.9840,	val_loss: 0.9164
# 137:	[0s / 6s],		train_loss: 0.9781,	val_loss: 0.9150
# 138:	[0s / 6s],		train_loss: 0.9795,	val_loss: 0.9170
# 139:	[0s / 6s],		train_loss: 0.9727,	val_loss: 0.9161
# 140:	[0s / 6s],		train_loss: 0.9849,	val_loss: 0.9155
# 141:	[0s / 6s],		train_loss: 0.9791,	val_loss: 0.9169
# 142:	[0s / 6s],		train_loss: 0.9792,	val_loss: 0.9154
# 143:	[0s / 6s],		train_loss: 0.9776,	val_loss: 0.9174
# 144:	[0s / 6s],		train_loss: 0.9792,	val_loss: 0.9167
# 145:	[0s / 6s],		train_loss: 0.9736,	val_loss: 0.9167
# 146:	[0s / 6s],		train_loss: 0.9743,	val_loss: 0.9182
# 147:	[0s / 6s],		train_loss: 0.9771,	val_loss: 0.9144
# 148:	[0s / 7s],		train_loss: 0.9732,	val_loss: 0.9154
# 149:	[0s / 7s],		train_loss: 0.9750,	val_loss: 0.9151
# 150:	[0s / 7s],		train_loss: 0.9800,	val_loss: 0.9167
# 151:	[0s / 7s],		train_loss: 0.9715,	val_loss: 0.9159
# 152:	[0s / 7s],		train_loss: 0.9783,	val_loss: 0.9146
# 153:	[0s / 7s],		train_loss: 0.9776,	val_loss: 0.9134
# 154:	[0s / 7s],		train_loss: 0.9732,	val_loss: 0.9154
# 155:	[0s / 7s],		train_loss: 0.9750,	val_loss: 0.9133
# 156:	[0s / 7s],		train_loss: 0.9764,	val_loss: 0.9133
# 157:	[0s / 7s],		train_loss: 0.9755,	val_loss: 0.9135
# 158:	[0s / 7s],		train_loss: 0.9732,	val_loss: 0.9123
# 159:	[0s / 7s],		train_loss: 0.9708,	val_loss: 0.9116
# 160:	[0s / 7s],		train_loss: 0.9774,	val_loss: 0.9108
# 161:	[0s / 7s],		train_loss: 0.9758,	val_loss: 0.9119
# 162:	[0s / 7s],		train_loss: 0.9725,	val_loss: 0.9133
# 163:	[0s / 7s],		train_loss: 0.9681,	val_loss: 0.9122
# 164:	[0s / 7s],		train_loss: 0.9780,	val_loss: 0.9119
# 165:	[0s / 7s],		train_loss: 0.9709,	val_loss: 0.9099
# 166:	[0s / 7s],		train_loss: 0.9644,	val_loss: 0.9113
# 167:	[0s / 7s],		train_loss: 0.9715,	val_loss: 0.9097
# 168:	[0s / 7s],		train_loss: 0.9687,	val_loss: 0.9106
# 169:	[0s / 8s],		train_loss: 0.9708,	val_loss: 0.9103
# 170:	[0s / 8s],		train_loss: 0.9700,	val_loss: 0.9101
# 171:	[0s / 8s],		train_loss: 0.9675,	val_loss: 0.9076
# 172:	[0s / 8s],		train_loss: 0.9722,	val_loss: 0.9082
# 173:	[0s / 8s],		train_loss: 0.9694,	val_loss: 0.9109
# 174:	[0s / 8s],		train_loss: 0.9649,	val_loss: 0.9104
# 175:	[0s / 8s],		train_loss: 0.9681,	val_loss: 0.9099
# 176:	[0s / 8s],		train_loss: 0.9732,	val_loss: 0.9089
# 177:	[0s / 8s],		train_loss: 0.9700,	val_loss: 0.9074
# 178:	[0s / 8s],		train_loss: 0.9730,	val_loss: 0.9074
# 179:	[0s / 8s],		train_loss: 0.9665,	val_loss: 0.9074
# 180:	[0s / 8s],		train_loss: 0.9665,	val_loss: 0.9074
# 181:	[0s / 8s],		train_loss: 0.9585,	val_loss: 0.9086
# 182:	[0s / 8s],		train_loss: 0.9659,	val_loss: 0.9083
# 183:	[0s / 8s],		train_loss: 0.9593,	val_loss: 0.9090
# 184:	[0s / 8s],		train_loss: 0.9647,	val_loss: 0.9081
# 185:	[0s / 8s],		train_loss: 0.9714,	val_loss: 0.9067
# 186:	[0s / 8s],		train_loss: 0.9714,	val_loss: 0.9087
# 187:	[0s / 8s],		train_loss: 0.9673,	val_loss: 0.9067
# 188:	[0s / 8s],		train_loss: 0.9605,	val_loss: 0.9086
# 189:	[0s / 8s],		train_loss: 0.9635,	val_loss: 0.9074
# 190:	[0s / 8s],		train_loss: 0.9622,	val_loss: 0.9073
# 191:	[0s / 9s],		train_loss: 0.9659,	val_loss: 0.9074
# 192:	[0s / 9s],		train_loss: 0.9672,	val_loss: 0.9078
# 193:	[0s / 9s],		train_loss: 0.9607,	val_loss: 0.9064
# 194:	[0s / 9s],		train_loss: 0.9638,	val_loss: 0.9075
# 195:	[0s / 9s],		train_loss: 0.9678,	val_loss: 0.9044
# 196:	[0s / 9s],		train_loss: 0.9601,	val_loss: 0.9050
# 197:	[0s / 9s],		train_loss: 0.9649,	val_loss: 0.9054
# 198:	[0s / 9s],		train_loss: 0.9626,	val_loss: 0.9032
# 199:	[0s / 9s],		train_loss: 0.9646,	val_loss: 0.9051
# 200:	[0s / 9s],		train_loss: 0.9599,	val_loss: 0.9032
# 201:	[0s / 9s],		train_loss: 0.9605,	val_loss: 0.9022
# 202:	[0s / 9s],		train_loss: 0.9541,	val_loss: 0.9041
# 203:	[0s / 9s],		train_loss: 0.9598,	val_loss: 0.9029
# 204:	[0s / 9s],		train_loss: 0.9661,	val_loss: 0.9034
# 205:	[0s / 9s],		train_loss: 0.9573,	val_loss: 0.9039
# 206:	[0s / 9s],		train_loss: 0.9574,	val_loss: 0.9027
# 207:	[0s / 9s],		train_loss: 0.9635,	val_loss: 0.9041
# 208:	[0s / 9s],		train_loss: 0.9638,	val_loss: 0.9031
# 209:	[0s / 9s],		train_loss: 0.9634,	val_loss: 0.9044
# 210:	[0s / 9s],		train_loss: 0.9561,	val_loss: 0.9055
# 211:	[0s / 9s],		train_loss: 0.9597,	val_loss: 0.9033
# 212:	[0s / 9s],		train_loss: 0.9571,	val_loss: 0.9046
# 213:	[0s / 9s],		train_loss: 0.9617,	val_loss: 0.9005
# 214:	[0s / 10s],		train_loss: 0.9603,	val_loss: 0.9019
# 215:	[0s / 10s],		train_loss: 0.9564,	val_loss: 0.9012
# 216:	[0s / 10s],		train_loss: 0.9575,	val_loss: 0.9013
# 217:	[0s / 10s],		train_loss: 0.9564,	val_loss: 0.9018
# 218:	[0s / 10s],		train_loss: 0.9558,	val_loss: 0.9026
# 219:	[0s / 10s],		train_loss: 0.9521,	val_loss: 0.8999
# 220:	[0s / 10s],		train_loss: 0.9565,	val_loss: 0.8993
# 221:	[0s / 10s],		train_loss: 0.9550,	val_loss: 0.9016
# 222:	[0s / 10s],		train_loss: 0.9586,	val_loss: 0.9014
# 223:	[0s / 10s],		train_loss: 0.9579,	val_loss: 0.9019
# 224:	[0s / 10s],		train_loss: 0.9551,	val_loss: 0.9050
# 225:	[0s / 10s],		train_loss: 0.9593,	val_loss: 0.9010
# 226:	[0s / 10s],		train_loss: 0.9565,	val_loss: 0.8994
# 227:	[0s / 10s],		train_loss: 0.9552,	val_loss: 0.8998
# 228:	[0s / 10s],		train_loss: 0.9557,	val_loss: 0.9012
# 229:	[0s / 10s],		train_loss: 0.9543,	val_loss: 0.9010
# 230:	[0s / 10s],		train_loss: 0.9542,	val_loss: 0.9004
# 231:	[0s / 10s],		train_loss: 0.9565,	val_loss: 0.8988
# 232:	[0s / 10s],		train_loss: 0.9586,	val_loss: 0.8986
# 233:	[0s / 10s],		train_loss: 0.9554,	val_loss: 0.8993
# 234:	[0s / 10s],		train_loss: 0.9484,	val_loss: 0.8990
# 235:	[0s / 10s],		train_loss: 0.9529,	val_loss: 0.8989
# 236:	[0s / 10s],		train_loss: 0.9591,	val_loss: 0.8991
# 237:	[0s / 11s],		train_loss: 0.9492,	val_loss: 0.8993
# 238:	[0s / 11s],		train_loss: 0.9478,	val_loss: 0.8977
# 239:	[0s / 11s],		train_loss: 0.9529,	val_loss: 0.8991
# 240:	[0s / 11s],		train_loss: 0.9451,	val_loss: 0.8994
# 241:	[0s / 11s],		train_loss: 0.9522,	val_loss: 0.8979
# 242:	[0s / 11s],		train_loss: 0.9501,	val_loss: 0.8981
# 243:	[0s / 11s],		train_loss: 0.9533,	val_loss: 0.8967
# 244:	[0s / 11s],		train_loss: 0.9580,	val_loss: 0.8972
# 245:	[0s / 11s],		train_loss: 0.9469,	val_loss: 0.8970
# 246:	[0s / 11s],		train_loss: 0.9546,	val_loss: 0.8981
# 247:	[0s / 11s],		train_loss: 0.9529,	val_loss: 0.8976
# 248:	[0s / 11s],		train_loss: 0.9465,	val_loss: 0.8995
# 249:	[0s / 11s],		train_loss: 0.9468,	val_loss: 0.8976
# 250:	[0s / 11s],		train_loss: 0.9469,	val_loss: 0.8965
# 251:	[0s / 11s],		train_loss: 0.9453,	val_loss: 0.8970
# 252:	[0s / 11s],		train_loss: 0.9499,	val_loss: 0.8940
# 253:	[0s / 11s],		train_loss: 0.9509,	val_loss: 0.8952
# 254:	[0s / 11s],		train_loss: 0.9423,	val_loss: 0.8963
# 255:	[0s / 11s],		train_loss: 0.9494,	val_loss: 0.8958
# 256:	[0s / 11s],		train_loss: 0.9460,	val_loss: 0.8960
# 257:	[0s / 11s],		train_loss: 0.9491,	val_loss: 0.8940
# 258:	[0s / 11s],		train_loss: 0.9480,	val_loss: 0.8958
# 259:	[0s / 12s],		train_loss: 0.9437,	val_loss: 0.8948
# 260:	[0s / 12s],		train_loss: 0.9463,	val_loss: 0.8942
# 261:	[0s / 12s],		train_loss: 0.9492,	val_loss: 0.8939
# 262:	[0s / 12s],		train_loss: 0.9442,	val_loss: 0.8947
# 263:	[0s / 12s],		train_loss: 0.9434,	val_loss: 0.8951
# 264:	[0s / 12s],		train_loss: 0.9411,	val_loss: 0.8960
# 265:	[0s / 12s],		train_loss: 0.9472,	val_loss: 0.8945
# 266:	[0s / 12s],		train_loss: 0.9439,	val_loss: 0.8956
# 267:	[0s / 12s],		train_loss: 0.9442,	val_loss: 0.8944
# 268:	[0s / 12s],		train_loss: 0.9457,	val_loss: 0.8937
# 269:	[0s / 12s],		train_loss: 0.9414,	val_loss: 0.8951
# 270:	[0s / 12s],		train_loss: 0.9455,	val_loss: 0.8938
# 271:	[0s / 12s],		train_loss: 0.9429,	val_loss: 0.8909
# 272:	[0s / 12s],		train_loss: 0.9449,	val_loss: 0.8917
# 273:	[0s / 12s],		train_loss: 0.9377,	val_loss: 0.8938
# 274:	[0s / 12s],		train_loss: 0.9433,	val_loss: 0.8913
# 275:	[0s / 12s],		train_loss: 0.9463,	val_loss: 0.8925
# 276:	[0s / 12s],		train_loss: 0.9414,	val_loss: 0.8933
# 277:	[0s / 12s],		train_loss: 0.9425,	val_loss: 0.8942
# 278:	[0s / 12s],		train_loss: 0.9402,	val_loss: 0.8924
# 279:	[0s / 12s],		train_loss: 0.9464,	val_loss: 0.8929
# 280:	[0s / 12s],		train_loss: 0.9421,	val_loss: 0.8928
# 281:	[0s / 12s],		train_loss: 0.9452,	val_loss: 0.8934
# 282:	[0s / 13s],		train_loss: 0.9402,	val_loss: 0.8899
# 283:	[0s / 13s],		train_loss: 0.9445,	val_loss: 0.8930
# 284:	[0s / 13s],		train_loss: 0.9410,	val_loss: 0.8906
# 285:	[0s / 13s],		train_loss: 0.9394,	val_loss: 0.8916
# 286:	[0s / 13s],		train_loss: 0.9420,	val_loss: 0.8914
# 287:	[0s / 13s],		train_loss: 0.9422,	val_loss: 0.8896
# 288:	[0s / 13s],		train_loss: 0.9370,	val_loss: 0.8893
# 289:	[0s / 13s],		train_loss: 0.9359,	val_loss: 0.8885
# 290:	[0s / 13s],		train_loss: 0.9393,	val_loss: 0.8897
# 291:	[0s / 13s],		train_loss: 0.9371,	val_loss: 0.8881
# 292:	[0s / 13s],		train_loss: 0.9407,	val_loss: 0.8886
# 293:	[0s / 13s],		train_loss: 0.9361,	val_loss: 0.8904
# 294:	[0s / 13s],		train_loss: 0.9379,	val_loss: 0.8901
# 295:	[0s / 13s],		train_loss: 0.9372,	val_loss: 0.8895
# 296:	[0s / 13s],		train_loss: 0.9379,	val_loss: 0.8883
# 297:	[0s / 13s],		train_loss: 0.9366,	val_loss: 0.8883
# 298:	[0s / 13s],		train_loss: 0.9378,	val_loss: 0.8891
# 299:	[0s / 13s],		train_loss: 0.9372,	val_loss: 0.8889
# 300:	[0s / 13s],		train_loss: 0.9417,	val_loss: 0.8882
# 301:	[0s / 13s],		train_loss: 0.9366,	val_loss: 0.8873
# 302:	[0s / 13s],		train_loss: 0.9373,	val_loss: 0.8871
# 303:	[0s / 13s],		train_loss: 0.9356,	val_loss: 0.8881
# 304:	[0s / 13s],		train_loss: 0.9338,	val_loss: 0.8871
# 305:	[0s / 14s],		train_loss: 0.9356,	val_loss: 0.8876
# 306:	[0s / 14s],		train_loss: 0.9404,	val_loss: 0.8887
# 307:	[0s / 14s],		train_loss: 0.9383,	val_loss: 0.8873
# 308:	[0s / 14s],		train_loss: 0.9348,	val_loss: 0.8888
# 309:	[0s / 14s],		train_loss: 0.9389,	val_loss: 0.8891
# 310:	[0s / 14s],		train_loss: 0.9387,	val_loss: 0.8882
# 311:	[0s / 14s],		train_loss: 0.9332,	val_loss: 0.8879
# 312:	[0s / 14s],		train_loss: 0.9330,	val_loss: 0.8876
# 313:	[0s / 14s],		train_loss: 0.9386,	val_loss: 0.8870
# 314:	[0s / 14s],		train_loss: 0.9341,	val_loss: 0.8864
# 315:	[0s / 14s],		train_loss: 0.9330,	val_loss: 0.8866
# 316:	[0s / 14s],		train_loss: 0.9344,	val_loss: 0.8865
# 317:	[0s / 14s],		train_loss: 0.9334,	val_loss: 0.8859
# 318:	[0s / 14s],		train_loss: 0.9355,	val_loss: 0.8866
# 319:	[0s / 14s],		train_loss: 0.9347,	val_loss: 0.8858
# 320:	[0s / 14s],		train_loss: 0.9367,	val_loss: 0.8848
# 321:	[0s / 14s],		train_loss: 0.9354,	val_loss: 0.8868
# 322:	[0s / 14s],		train_loss: 0.9377,	val_loss: 0.8854
# 323:	[0s / 14s],		train_loss: 0.9340,	val_loss: 0.8850
# 324:	[0s / 15s],		train_loss: 0.9326,	val_loss: 0.8848
# 325:	[0s / 15s],		train_loss: 0.9373,	val_loss: 0.8843
# 326:	[0s / 15s],		train_loss: 0.9366,	val_loss: 0.8840
# 327:	[0s / 15s],		train_loss: 0.9351,	val_loss: 0.8860
# 328:	[0s / 15s],		train_loss: 0.9324,	val_loss: 0.8857
# 329:	[0s / 15s],		train_loss: 0.9243,	val_loss: 0.8860
# 330:	[0s / 15s],		train_loss: 0.9310,	val_loss: 0.8849
# 331:	[0s / 15s],		train_loss: 0.9333,	val_loss: 0.8830
# 332:	[0s / 15s],		train_loss: 0.9302,	val_loss: 0.8850
# 333:	[0s / 15s],		train_loss: 0.9298,	val_loss: 0.8845
# 334:	[0s / 15s],		train_loss: 0.9277,	val_loss: 0.8871
# 335:	[0s / 15s],		train_loss: 0.9290,	val_loss: 0.8852
# 336:	[0s / 15s],		train_loss: 0.9370,	val_loss: 0.8835
# 337:	[0s / 15s],		train_loss: 0.9361,	val_loss: 0.8829
# 338:	[0s / 15s],		train_loss: 0.9337,	val_loss: 0.8841
# 339:	[0s / 15s],		train_loss: 0.9273,	val_loss: 0.8844
# 340:	[0s / 15s],		train_loss: 0.9329,	val_loss: 0.8850
# 341:	[0s / 15s],		train_loss: 0.9288,	val_loss: 0.8831
# 342:	[0s / 15s],		train_loss: 0.9280,	val_loss: 0.8851
# 343:	[0s / 16s],		train_loss: 0.9268,	val_loss: 0.8833
# 344:	[0s / 16s],		train_loss: 0.9264,	val_loss: 0.8840
# 345:	[0s / 16s],		train_loss: 0.9266,	val_loss: 0.8836
# 346:	[0s / 16s],		train_loss: 0.9285,	val_loss: 0.8830
# 347:	[0s / 16s],		train_loss: 0.9293,	val_loss: 0.8831
# 348:	[0s / 16s],		train_loss: 0.9300,	val_loss: 0.8834
# 349:	[0s / 16s],		train_loss: 0.9259,	val_loss: 0.8822
# 350:	[0s / 16s],		train_loss: 0.9251,	val_loss: 0.8804
# 351:	[0s / 16s],		train_loss: 0.9253,	val_loss: 0.8794
# 352:	[0s / 16s],		train_loss: 0.9292,	val_loss: 0.8841
# 353:	[0s / 16s],		train_loss: 0.9273,	val_loss: 0.8836
# 354:	[0s / 16s],		train_loss: 0.9288,	val_loss: 0.8820
# 355:	[0s / 16s],		train_loss: 0.9259,	val_loss: 0.8809
# 356:	[0s / 16s],		train_loss: 0.9319,	val_loss: 0.8789
# 357:	[0s / 16s],		train_loss: 0.9250,	val_loss: 0.8804
# 358:	[0s / 16s],		train_loss: 0.9275,	val_loss: 0.8800
# 359:	[0s / 17s],		train_loss: 0.9275,	val_loss: 0.8821
# 360:	[0s / 17s],		train_loss: 0.9284,	val_loss: 0.8805
# 361:	[0s / 17s],		train_loss: 0.9234,	val_loss: 0.8821
# 362:	[0s / 17s],		train_loss: 0.9305,	val_loss: 0.8799
# 363:	[0s / 17s],		train_loss: 0.9298,	val_loss: 0.8804
# 364:	[0s / 17s],		train_loss: 0.9259,	val_loss: 0.8808
# 365:	[0s / 17s],		train_loss: 0.9245,	val_loss: 0.8830
# 366:	[0s / 17s],		train_loss: 0.9279,	val_loss: 0.8798
# 367:	[0s / 17s],		train_loss: 0.9278,	val_loss: 0.8803
# 368:	[0s / 17s],		train_loss: 0.9220,	val_loss: 0.8791
# 369:	[0s / 17s],		train_loss: 0.9231,	val_loss: 0.8792
# 370:	[0s / 17s],		train_loss: 0.9271,	val_loss: 0.8780
# 371:	[0s / 17s],		train_loss: 0.9246,	val_loss: 0.8814
# 372:	[0s / 17s],		train_loss: 0.9201,	val_loss: 0.8806
# 373:	[0s / 17s],		train_loss: 0.9241,	val_loss: 0.8828
# 374:	[0s / 17s],		train_loss: 0.9275,	val_loss: 0.8784
# 375:	[0s / 17s],		train_loss: 0.9215,	val_loss: 0.8797
# 376:	[0s / 17s],		train_loss: 0.9240,	val_loss: 0.8780
# 377:	[0s / 18s],		train_loss: 0.9189,	val_loss: 0.8801
# 378:	[0s / 18s],		train_loss: 0.9187,	val_loss: 0.8800
# 379:	[0s / 18s],		train_loss: 0.9260,	val_loss: 0.8787
# 380:	[0s / 18s],		train_loss: 0.9215,	val_loss: 0.8792
# 381:	[0s / 18s],		train_loss: 0.9232,	val_loss: 0.8780
# 382:	[0s / 18s],		train_loss: 0.9246,	val_loss: 0.8794
# 383:	[0s / 18s],		train_loss: 0.9228,	val_loss: 0.8787
# 384:	[0s / 18s],		train_loss: 0.9219,	val_loss: 0.8778
# 385:	[0s / 18s],		train_loss: 0.9236,	val_loss: 0.8783
# 386:	[0s / 18s],		train_loss: 0.9175,	val_loss: 0.8788
# 387:	[0s / 18s],		train_loss: 0.9235,	val_loss: 0.8775
# 388:	[0s / 18s],		train_loss: 0.9179,	val_loss: 0.8766
# 389:	[0s / 18s],		train_loss: 0.9233,	val_loss: 0.8772
# 390:	[0s / 18s],		train_loss: 0.9188,	val_loss: 0.8786
# 391:	[0s / 18s],		train_loss: 0.9191,	val_loss: 0.8777
# 392:	[0s / 18s],		train_loss: 0.9159,	val_loss: 0.8774
# 393:	[0s / 18s],		train_loss: 0.9187,	val_loss: 0.8774
# 394:	[0s / 18s],		train_loss: 0.9219,	val_loss: 0.8770
# 395:	[0s / 18s],		train_loss: 0.9219,	val_loss: 0.8749
# 396:	[0s / 18s],		train_loss: 0.9239,	val_loss: 0.8748
# 397:	[0s / 19s],		train_loss: 0.9233,	val_loss: 0.8759
# 398:	[0s / 19s],		train_loss: 0.9168,	val_loss: 0.8756
# 399:	[0s / 19s],		train_loss: 0.9225,	val_loss: 0.8764
# 400:	[0s / 19s],		train_loss: 0.9182,	val_loss: 0.8771
# 401:	[0s / 19s],		train_loss: 0.9210,	val_loss: 0.8763
# 402:	[0s / 19s],		train_loss: 0.9126,	val_loss: 0.8774
# 403:	[0s / 19s],		train_loss: 0.9216,	val_loss: 0.8761
# 404:	[0s / 19s],		train_loss: 0.9226,	val_loss: 0.8764
# 405:	[0s / 19s],		train_loss: 0.9203,	val_loss: 0.8775
# 406:	[0s / 19s],		train_loss: 0.9222,	val_loss: 0.8756
# 407:	[0s / 19s],		train_loss: 0.9185,	val_loss: 0.8754
# 408:	[0s / 19s],		train_loss: 0.9113,	val_loss: 0.8762
# 409:	[0s / 19s],		train_loss: 0.9186,	val_loss: 0.8759
# 410:	[0s / 19s],		train_loss: 0.9204,	val_loss: 0.8748
# 411:	[0s / 19s],		train_loss: 0.9239,	val_loss: 0.8728
# 412:	[0s / 19s],		train_loss: 0.9181,	val_loss: 0.8736
# 413:	[0s / 19s],		train_loss: 0.9207,	val_loss: 0.8741
# 414:	[0s / 19s],		train_loss: 0.9151,	val_loss: 0.8758
# 415:	[0s / 19s],		train_loss: 0.9181,	val_loss: 0.8750
# 416:	[0s / 19s],		train_loss: 0.9168,	val_loss: 0.8738
# 417:	[0s / 19s],		train_loss: 0.9188,	val_loss: 0.8740
# 418:	[0s / 19s],		train_loss: 0.9216,	val_loss: 0.8748
# 419:	[0s / 20s],		train_loss: 0.9085,	val_loss: 0.8736
# 420:	[0s / 20s],		train_loss: 0.9147,	val_loss: 0.8733
# 421:	[0s / 20s],		train_loss: 0.9184,	val_loss: 0.8748
# 422:	[0s / 20s],		train_loss: 0.9204,	val_loss: 0.8731
# 423:	[0s / 20s],		train_loss: 0.9156,	val_loss: 0.8732
# 424:	[0s / 20s],		train_loss: 0.9171,	val_loss: 0.8746
# 425:	[0s / 20s],		train_loss: 0.9199,	val_loss: 0.8744
# 426:	[0s / 20s],		train_loss: 0.9171,	val_loss: 0.8736
# 427:	[0s / 20s],		train_loss: 0.9150,	val_loss: 0.8716
# 428:	[0s / 20s],		train_loss: 0.9143,	val_loss: 0.8718
# 429:	[0s / 20s],		train_loss: 0.9142,	val_loss: 0.8706
# 430:	[0s / 20s],		train_loss: 0.9151,	val_loss: 0.8712
# 431:	[0s / 20s],		train_loss: 0.9158,	val_loss: 0.8713
# 432:	[0s / 20s],		train_loss: 0.9169,	val_loss: 0.8715
# 433:	[0s / 20s],		train_loss: 0.9166,	val_loss: 0.8724
# 434:	[0s / 20s],		train_loss: 0.9133,	val_loss: 0.8721
# 435:	[0s / 20s],		train_loss: 0.9128,	val_loss: 0.8706
# 436:	[0s / 20s],		train_loss: 0.9145,	val_loss: 0.8713
# 437:	[0s / 20s],		train_loss: 0.9141,	val_loss: 0.8712
# 438:	[0s / 20s],		train_loss: 0.9161,	val_loss: 0.8704
# 439:	[0s / 20s],		train_loss: 0.9081,	val_loss: 0.8716
# 440:	[0s / 20s],		train_loss: 0.9161,	val_loss: 0.8707
# 441:	[0s / 20s],		train_loss: 0.9130,	val_loss: 0.8706
# 442:	[0s / 21s],		train_loss: 0.9095,	val_loss: 0.8732
# 443:	[0s / 21s],		train_loss: 0.9117,	val_loss: 0.8727
# 444:	[0s / 21s],		train_loss: 0.9062,	val_loss: 0.8720
# 445:	[0s / 21s],		train_loss: 0.9150,	val_loss: 0.8705
# 446:	[0s / 21s],		train_loss: 0.9086,	val_loss: 0.8708
# 447:	[0s / 21s],		train_loss: 0.9117,	val_loss: 0.8701
# 448:	[0s / 21s],		train_loss: 0.9170,	val_loss: 0.8710
# 449:	[0s / 21s],		train_loss: 0.9204,	val_loss: 0.8721
# 450:	[0s / 21s],		train_loss: 0.9125,	val_loss: 0.8717
# 451:	[0s / 21s],		train_loss: 0.9134,	val_loss: 0.8714
# 452:	[0s / 21s],		train_loss: 0.9109,	val_loss: 0.8723
# 453:	[0s / 21s],		train_loss: 0.9082,	val_loss: 0.8725
# 454:	[0s / 21s],		train_loss: 0.9058,	val_loss: 0.8709
# 455:	[0s / 21s],		train_loss: 0.9104,	val_loss: 0.8710
# 456:	[0s / 21s],		train_loss: 0.9061,	val_loss: 0.8701
# 457:	[0s / 21s],		train_loss: 0.9082,	val_loss: 0.8706
# 458:	[0s / 21s],		train_loss: 0.9063,	val_loss: 0.8695
# 459:	[0s / 21s],		train_loss: 0.9150,	val_loss: 0.8693
# 460:	[0s / 21s],		train_loss: 0.9079,	val_loss: 0.8700
# 461:	[0s / 21s],		train_loss: 0.9117,	val_loss: 0.8699
# 462:	[0s / 21s],		train_loss: 0.9071,	val_loss: 0.8708
# 463:	[0s / 21s],		train_loss: 0.9094,	val_loss: 0.8687
# 464:	[0s / 22s],		train_loss: 0.9092,	val_loss: 0.8695
# 465:	[0s / 22s],		train_loss: 0.9118,	val_loss: 0.8691
# 466:	[0s / 22s],		train_loss: 0.9112,	val_loss: 0.8690
# 467:	[0s / 22s],		train_loss: 0.9085,	val_loss: 0.8681
# 468:	[0s / 22s],		train_loss: 0.9125,	val_loss: 0.8672
# 469:	[0s / 22s],		train_loss: 0.9081,	val_loss: 0.8680
# 470:	[0s / 22s],		train_loss: 0.9087,	val_loss: 0.8682
# 471:	[0s / 22s],		train_loss: 0.9055,	val_loss: 0.8697
# 472:	[0s / 22s],		train_loss: 0.9081,	val_loss: 0.8698
# 473:	[0s / 22s],		train_loss: 0.9061,	val_loss: 0.8680
# 474:	[0s / 22s],		train_loss: 0.9087,	val_loss: 0.8674
# 475:	[0s / 22s],		train_loss: 0.9040,	val_loss: 0.8672
# 476:	[0s / 22s],		train_loss: 0.9083,	val_loss: 0.8671
# 477:	[0s / 22s],		train_loss: 0.9066,	val_loss: 0.8685
# 478:	[0s / 22s],		train_loss: 0.9089,	val_loss: 0.8675
# 479:	[0s / 22s],		train_loss: 0.9099,	val_loss: 0.8695
# 480:	[0s / 22s],		train_loss: 0.9055,	val_loss: 0.8667
# 481:	[0s / 22s],		train_loss: 0.9054,	val_loss: 0.8683
# 482:	[0s / 22s],		train_loss: 0.9061,	val_loss: 0.8681
# 483:	[0s / 22s],		train_loss: 0.9066,	val_loss: 0.8665
# 484:	[0s / 23s],		train_loss: 0.9050,	val_loss: 0.8670
# 485:	[0s / 23s],		train_loss: 0.9019,	val_loss: 0.8668
# 486:	[0s / 23s],		train_loss: 0.9079,	val_loss: 0.8671
# 487:	[0s / 23s],		train_loss: 0.9038,	val_loss: 0.8669
# 488:	[0s / 23s],		train_loss: 0.9066,	val_loss: 0.8662
# 489:	[0s / 23s],		train_loss: 0.9069,	val_loss: 0.8675
# 490:	[0s / 23s],		train_loss: 0.9052,	val_loss: 0.8661
# 491:	[0s / 23s],		train_loss: 0.9079,	val_loss: 0.8673
# 492:	[0s / 23s],		train_loss: 0.8963,	val_loss: 0.8659
# 493:	[0s / 23s],		train_loss: 0.9032,	val_loss: 0.8665
# 494:	[0s / 23s],		train_loss: 0.9043,	val_loss: 0.8665
# 495:	[0s / 23s],		train_loss: 0.8993,	val_loss: 0.8672
# 496:	[0s / 23s],		train_loss: 0.9034,	val_loss: 0.8675
# 497:	[0s / 23s],		train_loss: 0.9050,	val_loss: 0.8668
# 498:	[0s / 23s],		train_loss: 0.9027,	val_loss: 0.8647
# 499:	[0s / 23s],		train_loss: 0.9032,	val_loss: 0.8662
# 500:	[0s / 23s],		train_loss: 0.9033,	val_loss: 0.8633
# 501:	[0s / 23s],		train_loss: 0.9032,	val_loss: 0.8655
# 502:	[0s / 24s],		train_loss: 0.9029,	val_loss: 0.8655
# 503:	[0s / 24s],		train_loss: 0.9019,	val_loss: 0.8644
# 504:	[0s / 24s],		train_loss: 0.9051,	val_loss: 0.8636
# 505:	[0s / 24s],		train_loss: 0.9065,	val_loss: 0.8645
# 506:	[0s / 24s],		train_loss: 0.9032,	val_loss: 0.8648
# 507:	[0s / 24s],		train_loss: 0.9028,	val_loss: 0.8647
# 508:	[0s / 24s],		train_loss: 0.8992,	val_loss: 0.8646
# 509:	[0s / 24s],		train_loss: 0.8993,	val_loss: 0.8642
# 510:	[0s / 24s],		train_loss: 0.9003,	val_loss: 0.8645
# 511:	[0s / 24s],		train_loss: 0.9016,	val_loss: 0.8646
# 512:	[0s / 24s],		train_loss: 0.9027,	val_loss: 0.8635
# 513:	[0s / 24s],		train_loss: 0.9015,	val_loss: 0.8632
# 514:	[0s / 24s],		train_loss: 0.9047,	val_loss: 0.8624
# 515:	[0s / 24s],		train_loss: 0.9038,	val_loss: 0.8640
# 516:	[0s / 24s],		train_loss: 0.9013,	val_loss: 0.8634
# 517:	[0s / 24s],		train_loss: 0.8978,	val_loss: 0.8631
# 518:	[0s / 24s],		train_loss: 0.8981,	val_loss: 0.8637
# 519:	[0s / 24s],		train_loss: 0.8996,	val_loss: 0.8621
# 520:	[0s / 24s],		train_loss: 0.8993,	val_loss: 0.8627
# 521:	[0s / 24s],		train_loss: 0.8975,	val_loss: 0.8628
# 522:	[0s / 25s],		train_loss: 0.9000,	val_loss: 0.8629
# 523:	[0s / 25s],		train_loss: 0.9007,	val_loss: 0.8636
# 524:	[0s / 25s],		train_loss: 0.8997,	val_loss: 0.8629
# 525:	[0s / 25s],		train_loss: 0.9001,	val_loss: 0.8624
# 526:	[0s / 25s],		train_loss: 0.9007,	val_loss: 0.8614
# 527:	[0s / 25s],		train_loss: 0.9022,	val_loss: 0.8615
# 528:	[0s / 25s],		train_loss: 0.9001,	val_loss: 0.8631
# 529:	[0s / 25s],		train_loss: 0.9007,	val_loss: 0.8630
# 530:	[0s / 25s],		train_loss: 0.8993,	val_loss: 0.8619
# 531:	[0s / 25s],		train_loss: 0.9027,	val_loss: 0.8629
# 532:	[0s / 25s],		train_loss: 0.8988,	val_loss: 0.8612
# 533:	[0s / 25s],		train_loss: 0.8997,	val_loss: 0.8612
# 534:	[0s / 25s],		train_loss: 0.8999,	val_loss: 0.8607
# 535:	[0s / 25s],		train_loss: 0.9002,	val_loss: 0.8604
# 536:	[0s / 25s],		train_loss: 0.9003,	val_loss: 0.8616
# 537:	[0s / 25s],		train_loss: 0.8950,	val_loss: 0.8608
# 538:	[0s / 25s],		train_loss: 0.8984,	val_loss: 0.8598
# 539:	[0s / 25s],		train_loss: 0.8955,	val_loss: 0.8609
# 540:	[0s / 25s],		train_loss: 0.8989,	val_loss: 0.8612
# 541:	[0s / 25s],		train_loss: 0.8983,	val_loss: 0.8604
# 542:	[0s / 25s],		train_loss: 0.8928,	val_loss: 0.8603
# 543:	[0s / 26s],		train_loss: 0.8954,	val_loss: 0.8607
# 544:	[0s / 26s],		train_loss: 0.8950,	val_loss: 0.8614
# 545:	[0s / 26s],		train_loss: 0.8987,	val_loss: 0.8630
# 546:	[0s / 26s],		train_loss: 0.8981,	val_loss: 0.8629
# 547:	[0s / 26s],		train_loss: 0.8936,	val_loss: 0.8625
# 548:	[0s / 26s],		train_loss: 0.8947,	val_loss: 0.8625
# 549:	[0s / 26s],		train_loss: 0.8969,	val_loss: 0.8619
# 550:	[0s / 26s],		train_loss: 0.8974,	val_loss: 0.8609
# 551:	[0s / 26s],		train_loss: 0.8979,	val_loss: 0.8594
# 552:	[0s / 26s],		train_loss: 0.8975,	val_loss: 0.8602
# 553:	[0s / 26s],		train_loss: 0.8991,	val_loss: 0.8618
# 554:	[0s / 26s],		train_loss: 0.8956,	val_loss: 0.8602
# 555:	[0s / 26s],		train_loss: 0.8972,	val_loss: 0.8607
# 556:	[0s / 26s],		train_loss: 0.8928,	val_loss: 0.8601
# 557:	[0s / 26s],		train_loss: 0.8942,	val_loss: 0.8594
# 558:	[0s / 26s],		train_loss: 0.8932,	val_loss: 0.8599
# 559:	[0s / 26s],		train_loss: 0.8974,	val_loss: 0.8604
# 560:	[0s / 26s],		train_loss: 0.8952,	val_loss: 0.8593
# 561:	[0s / 26s],		train_loss: 0.8942,	val_loss: 0.8592
# 562:	[0s / 26s],		train_loss: 0.8953,	val_loss: 0.8588
# 563:	[0s / 26s],		train_loss: 0.8981,	val_loss: 0.8574
# 564:	[0s / 27s],		train_loss: 0.8951,	val_loss: 0.8586
# 565:	[0s / 27s],		train_loss: 0.8933,	val_loss: 0.8585
# 566:	[0s / 27s],		train_loss: 0.8957,	val_loss: 0.8582
# 567:	[0s / 27s],		train_loss: 0.8963,	val_loss: 0.8594
# 568:	[0s / 27s],		train_loss: 0.8974,	val_loss: 0.8596
# 569:	[0s / 27s],		train_loss: 0.8951,	val_loss: 0.8597
# 570:	[0s / 27s],		train_loss: 0.8935,	val_loss: 0.8606
# 571:	[0s / 27s],		train_loss: 0.8977,	val_loss: 0.8596
# 572:	[0s / 27s],		train_loss: 0.8951,	val_loss: 0.8585
# 573:	[0s / 27s],		train_loss: 0.8924,	val_loss: 0.8593
# 574:	[0s / 27s],		train_loss: 0.8920,	val_loss: 0.8590
# 575:	[0s / 27s],		train_loss: 0.8944,	val_loss: 0.8601
# 576:	[0s / 27s],		train_loss: 0.8894,	val_loss: 0.8583
# 577:	[0s / 27s],		train_loss: 0.8883,	val_loss: 0.8588
# 578:	[0s / 27s],		train_loss: 0.8936,	val_loss: 0.8591
# 579:	[0s / 27s],		train_loss: 0.8979,	val_loss: 0.8591
# 580:	[0s / 27s],		train_loss: 0.8930,	val_loss: 0.8574
# 581:	[0s / 27s],		train_loss: 0.8941,	val_loss: 0.8562
# 582:	[0s / 27s],		train_loss: 0.8967,	val_loss: 0.8566
# 583:	[0s / 27s],		train_loss: 0.8901,	val_loss: 0.8583
# 584:	[0s / 27s],		train_loss: 0.8915,	val_loss: 0.8583
# 585:	[0s / 27s],		train_loss: 0.8926,	val_loss: 0.8575
# 586:	[0s / 28s],		train_loss: 0.8937,	val_loss: 0.8560
# 587:	[0s / 28s],		train_loss: 0.8944,	val_loss: 0.8561
# 588:	[0s / 28s],		train_loss: 0.8938,	val_loss: 0.8554
# 589:	[0s / 28s],		train_loss: 0.8902,	val_loss: 0.8567
# 590:	[0s / 28s],		train_loss: 0.8901,	val_loss: 0.8581
# 591:	[0s / 28s],		train_loss: 0.8887,	val_loss: 0.8582
# 592:	[0s / 28s],		train_loss: 0.8930,	val_loss: 0.8577
# 593:	[0s / 28s],		train_loss: 0.8922,	val_loss: 0.8573
# 594:	[0s / 28s],		train_loss: 0.8910,	val_loss: 0.8579
# 595:	[0s / 28s],		train_loss: 0.8915,	val_loss: 0.8567
# 596:	[0s / 28s],		train_loss: 0.8920,	val_loss: 0.8567
# 597:	[0s / 28s],		train_loss: 0.8915,	val_loss: 0.8556
# 598:	[0s / 28s],		train_loss: 0.8904,	val_loss: 0.8552
# 599:	[0s / 28s],		train_loss: 0.8887,	val_loss: 0.8553
# 600:	[0s / 28s],		train_loss: 0.8888,	val_loss: 0.8560
# 601:	[0s / 28s],		train_loss: 0.8870,	val_loss: 0.8568
# 602:	[0s / 28s],		train_loss: 0.8898,	val_loss: 0.8561
# 603:	[0s / 28s],		train_loss: 0.8886,	val_loss: 0.8559
# 604:	[0s / 28s],		train_loss: 0.8906,	val_loss: 0.8547
# 605:	[0s / 28s],		train_loss: 0.8896,	val_loss: 0.8561
# 606:	[0s / 28s],		train_loss: 0.8901,	val_loss: 0.8544
# 607:	[0s / 28s],		train_loss: 0.8928,	val_loss: 0.8559
# 608:	[0s / 29s],		train_loss: 0.8914,	val_loss: 0.8550
# 609:	[0s / 29s],		train_loss: 0.8888,	val_loss: 0.8556
# 610:	[0s / 29s],		train_loss: 0.8903,	val_loss: 0.8549
# 611:	[0s / 29s],		train_loss: 0.8874,	val_loss: 0.8536
# 612:	[0s / 29s],		train_loss: 0.8882,	val_loss: 0.8552
# 613:	[0s / 29s],		train_loss: 0.8862,	val_loss: 0.8541
# 614:	[0s / 29s],		train_loss: 0.8888,	val_loss: 0.8546
# 615:	[0s / 29s],		train_loss: 0.8865,	val_loss: 0.8554
# 616:	[0s / 29s],		train_loss: 0.8827,	val_loss: 0.8538
# 617:	[0s / 29s],		train_loss: 0.8886,	val_loss: 0.8543
# 618:	[0s / 29s],		train_loss: 0.8871,	val_loss: 0.8542
# 619:	[0s / 29s],		train_loss: 0.8867,	val_loss: 0.8534
# 620:	[0s / 29s],		train_loss: 0.8896,	val_loss: 0.8539
# 621:	[0s / 29s],		train_loss: 0.8894,	val_loss: 0.8542
# 622:	[0s / 29s],		train_loss: 0.8860,	val_loss: 0.8540
# 623:	[0s / 29s],		train_loss: 0.8873,	val_loss: 0.8544
# 624:	[0s / 30s],		train_loss: 0.8878,	val_loss: 0.8538
# 625:	[0s / 30s],		train_loss: 0.8877,	val_loss: 0.8535
# 626:	[0s / 30s],		train_loss: 0.8894,	val_loss: 0.8542
# 627:	[0s / 30s],		train_loss: 0.8856,	val_loss: 0.8539
# 628:	[0s / 30s],		train_loss: 0.8843,	val_loss: 0.8549
# 629:	[0s / 30s],		train_loss: 0.8859,	val_loss: 0.8539
# 630:	[0s / 30s],		train_loss: 0.8834,	val_loss: 0.8527
# 631:	[0s / 30s],		train_loss: 0.8893,	val_loss: 0.8533
# 632:	[0s / 30s],		train_loss: 0.8878,	val_loss: 0.8533
# 633:	[0s / 30s],		train_loss: 0.8873,	val_loss: 0.8531
# 634:	[0s / 30s],		train_loss: 0.8797,	val_loss: 0.8527
# 635:	[0s / 30s],		train_loss: 0.8858,	val_loss: 0.8515
# 636:	[0s / 30s],		train_loss: 0.8826,	val_loss: 0.8532
# 637:	[0s / 30s],		train_loss: 0.8852,	val_loss: 0.8522
# 638:	[0s / 30s],		train_loss: 0.8837,	val_loss: 0.8539
# 639:	[0s / 30s],		train_loss: 0.8826,	val_loss: 0.8539
# 640:	[0s / 30s],		train_loss: 0.8840,	val_loss: 0.8540
# 641:	[0s / 30s],		train_loss: 0.8785,	val_loss: 0.8522
# 642:	[0s / 30s],		train_loss: 0.8851,	val_loss: 0.8529
# 643:	[0s / 30s],		train_loss: 0.8849,	val_loss: 0.8535
# 644:	[0s / 30s],		train_loss: 0.8854,	val_loss: 0.8523
# 645:	[0s / 31s],		train_loss: 0.8860,	val_loss: 0.8523
# 646:	[0s / 31s],		train_loss: 0.8855,	val_loss: 0.8512
# 647:	[0s / 31s],		train_loss: 0.8813,	val_loss: 0.8528
# 648:	[0s / 31s],		train_loss: 0.8856,	val_loss: 0.8526
# 649:	[0s / 31s],		train_loss: 0.8849,	val_loss: 0.8521
# 650:	[0s / 31s],		train_loss: 0.8872,	val_loss: 0.8527
# 651:	[0s / 31s],		train_loss: 0.8874,	val_loss: 0.8519
# 652:	[0s / 31s],		train_loss: 0.8839,	val_loss: 0.8517
# 653:	[0s / 31s],		train_loss: 0.8842,	val_loss: 0.8531
# 654:	[0s / 31s],		train_loss: 0.8833,	val_loss: 0.8526
# 655:	[0s / 31s],		train_loss: 0.8853,	val_loss: 0.8516
# 656:	[0s / 31s],		train_loss: 0.8795,	val_loss: 0.8516
# 657:	[0s / 31s],		train_loss: 0.8842,	val_loss: 0.8516
# 658:	[0s / 31s],		train_loss: 0.8813,	val_loss: 0.8512
# 659:	[0s / 31s],		train_loss: 0.8813,	val_loss: 0.8506
# 660:	[0s / 31s],		train_loss: 0.8832,	val_loss: 0.8509
# 661:	[0s / 31s],		train_loss: 0.8818,	val_loss: 0.8499
# 662:	[0s / 31s],		train_loss: 0.8813,	val_loss: 0.8507
# 663:	[0s / 31s],		train_loss: 0.8809,	val_loss: 0.8501
# 664:	[0s / 31s],		train_loss: 0.8850,	val_loss: 0.8501
# 665:	[0s / 31s],		train_loss: 0.8820,	val_loss: 0.8506
# 666:	[0s / 31s],		train_loss: 0.8828,	val_loss: 0.8497
# 667:	[0s / 31s],		train_loss: 0.8825,	val_loss: 0.8513
# 668:	[0s / 32s],		train_loss: 0.8827,	val_loss: 0.8499
# 669:	[0s / 32s],		train_loss: 0.8820,	val_loss: 0.8507
# 670:	[0s / 32s],		train_loss: 0.8824,	val_loss: 0.8500
# 671:	[0s / 32s],		train_loss: 0.8792,	val_loss: 0.8501
# 672:	[0s / 32s],		train_loss: 0.8820,	val_loss: 0.8490
# 673:	[0s / 32s],		train_loss: 0.8837,	val_loss: 0.8506
# 674:	[0s / 32s],		train_loss: 0.8834,	val_loss: 0.8499
# 675:	[0s / 32s],		train_loss: 0.8824,	val_loss: 0.8498
# 676:	[0s / 32s],		train_loss: 0.8808,	val_loss: 0.8482
# 677:	[0s / 32s],		train_loss: 0.8781,	val_loss: 0.8492
# 678:	[0s / 32s],		train_loss: 0.8790,	val_loss: 0.8491
# 679:	[0s / 32s],		train_loss: 0.8803,	val_loss: 0.8501
# 680:	[0s / 32s],		train_loss: 0.8806,	val_loss: 0.8502
# 681:	[0s / 32s],		train_loss: 0.8786,	val_loss: 0.8503
# 682:	[0s / 32s],		train_loss: 0.8799,	val_loss: 0.8494
# 683:	[0s / 32s],		train_loss: 0.8796,	val_loss: 0.8493
# 684:	[0s / 32s],		train_loss: 0.8795,	val_loss: 0.8492
# 685:	[0s / 32s],		train_loss: 0.8792,	val_loss: 0.8486
# 686:	[0s / 32s],		train_loss: 0.8791,	val_loss: 0.8508
# 687:	[0s / 32s],		train_loss: 0.8765,	val_loss: 0.8495
# 688:	[0s / 33s],		train_loss: 0.8793,	val_loss: 0.8492
# 689:	[0s / 33s],		train_loss: 0.8757,	val_loss: 0.8478
# 690:	[0s / 33s],		train_loss: 0.8782,	val_loss: 0.8483
# 691:	[0s / 33s],		train_loss: 0.8801,	val_loss: 0.8491
# 692:	[0s / 33s],		train_loss: 0.8762,	val_loss: 0.8485
# 693:	[0s / 33s],		train_loss: 0.8807,	val_loss: 0.8488
# 694:	[0s / 33s],		train_loss: 0.8804,	val_loss: 0.8497
# 695:	[0s / 33s],		train_loss: 0.8812,	val_loss: 0.8491
# 696:	[0s / 33s],		train_loss: 0.8783,	val_loss: 0.8476
# 697:	[0s / 33s],		train_loss: 0.8772,	val_loss: 0.8485
# 698:	[0s / 33s],		train_loss: 0.8800,	val_loss: 0.8480
# 699:	[0s / 33s],		train_loss: 0.8756,	val_loss: 0.8471
# 700:	[0s / 33s],		train_loss: 0.8803,	val_loss: 0.8483
# 701:	[0s / 33s],		train_loss: 0.8778,	val_loss: 0.8475
# 702:	[0s / 33s],		train_loss: 0.8788,	val_loss: 0.8470
# 703:	[0s / 33s],		train_loss: 0.8779,	val_loss: 0.8478
# 704:	[0s / 33s],		train_loss: 0.8780,	val_loss: 0.8469
# 705:	[0s / 33s],		train_loss: 0.8786,	val_loss: 0.8477
# 706:	[0s / 33s],		train_loss: 0.8758,	val_loss: 0.8467
# 707:	[0s / 33s],		train_loss: 0.8742,	val_loss: 0.8486
# 708:	[0s / 34s],		train_loss: 0.8752,	val_loss: 0.8483
# 709:	[0s / 34s],		train_loss: 0.8767,	val_loss: 0.8476
# 710:	[0s / 34s],		train_loss: 0.8753,	val_loss: 0.8473
# 711:	[0s / 34s],		train_loss: 0.8727,	val_loss: 0.8485
# 712:	[0s / 34s],		train_loss: 0.8732,	val_loss: 0.8479
# 713:	[0s / 34s],		train_loss: 0.8766,	val_loss: 0.8475
# 714:	[0s / 34s],		train_loss: 0.8774,	val_loss: 0.8469
# 715:	[0s / 34s],		train_loss: 0.8734,	val_loss: 0.8480
# 716:	[0s / 34s],		train_loss: 0.8755,	val_loss: 0.8492
# 717:	[0s / 34s],		train_loss: 0.8740,	val_loss: 0.8470
# 718:	[0s / 34s],		train_loss: 0.8782,	val_loss: 0.8461
# 719:	[0s / 34s],		train_loss: 0.8768,	val_loss: 0.8458
# 720:	[0s / 34s],		train_loss: 0.8729,	val_loss: 0.8460
# 721:	[0s / 34s],		train_loss: 0.8785,	val_loss: 0.8461
# 722:	[0s / 34s],		train_loss: 0.8782,	val_loss: 0.8448
# 723:	[0s / 34s],		train_loss: 0.8748,	val_loss: 0.8461
# 724:	[0s / 34s],		train_loss: 0.8745,	val_loss: 0.8473
# 725:	[0s / 34s],		train_loss: 0.8725,	val_loss: 0.8462
# 726:	[0s / 34s],		train_loss: 0.8725,	val_loss: 0.8465
# 727:	[0s / 34s],		train_loss: 0.8771,	val_loss: 0.8472
# 728:	[0s / 35s],		train_loss: 0.8763,	val_loss: 0.8467
# 729:	[0s / 35s],		train_loss: 0.8756,	val_loss: 0.8468
# 730:	[0s / 35s],		train_loss: 0.8774,	val_loss: 0.8460
# 731:	[0s / 35s],		train_loss: 0.8737,	val_loss: 0.8466
# 732:	[0s / 35s],		train_loss: 0.8746,	val_loss: 0.8455
# 733:	[0s / 35s],		train_loss: 0.8736,	val_loss: 0.8455
# 734:	[0s / 35s],		train_loss: 0.8756,	val_loss: 0.8459
# 735:	[0s / 35s],		train_loss: 0.8739,	val_loss: 0.8468
# 736:	[0s / 35s],		train_loss: 0.8760,	val_loss: 0.8460
# 737:	[0s / 35s],		train_loss: 0.8734,	val_loss: 0.8454
# 738:	[0s / 35s],		train_loss: 0.8763,	val_loss: 0.8447
# 739:	[0s / 35s],		train_loss: 0.8749,	val_loss: 0.8454
# 740:	[0s / 35s],		train_loss: 0.8733,	val_loss: 0.8450
# 741:	[0s / 35s],		train_loss: 0.8719,	val_loss: 0.8436
# 742:	[0s / 35s],		train_loss: 0.8744,	val_loss: 0.8429
# 743:	[0s / 35s],		train_loss: 0.8735,	val_loss: 0.8437
# 744:	[0s / 35s],		train_loss: 0.8729,	val_loss: 0.8441
# 745:	[0s / 35s],		train_loss: 0.8745,	val_loss: 0.8436
# 746:	[0s / 36s],		train_loss: 0.8701,	val_loss: 0.8433
# 747:	[0s / 36s],		train_loss: 0.8729,	val_loss: 0.8438
# 748:	[0s / 36s],		train_loss: 0.8722,	val_loss: 0.8449
# 749:	[0s / 36s],		train_loss: 0.8677,	val_loss: 0.8444
# 750:	[0s / 36s],		train_loss: 0.8759,	val_loss: 0.8445
# 751:	[0s / 36s],		train_loss: 0.8766,	val_loss: 0.8442
# 752:	[0s / 36s],		train_loss: 0.8711,	val_loss: 0.8439
# 753:	[0s / 36s],		train_loss: 0.8736,	val_loss: 0.8448
# 754:	[0s / 36s],		train_loss: 0.8740,	val_loss: 0.8450
# 755:	[0s / 36s],		train_loss: 0.8691,	val_loss: 0.8453
# 756:	[0s / 36s],		train_loss: 0.8731,	val_loss: 0.8445
# 757:	[0s / 36s],		train_loss: 0.8742,	val_loss: 0.8434
# 758:	[0s / 36s],		train_loss: 0.8705,	val_loss: 0.8435
# 759:	[0s / 36s],		train_loss: 0.8766,	val_loss: 0.8427
# 760:	[0s / 36s],		train_loss: 0.8710,	val_loss: 0.8443
# 761:	[0s / 36s],		train_loss: 0.8664,	val_loss: 0.8437
# 762:	[0s / 36s],		train_loss: 0.8730,	val_loss: 0.8435
# 763:	[0s / 36s],		train_loss: 0.8692,	val_loss: 0.8442
# 764:	[0s / 36s],		train_loss: 0.8696,	val_loss: 0.8424
# 765:	[0s / 36s],		train_loss: 0.8712,	val_loss: 0.8430
# 766:	[0s / 36s],		train_loss: 0.8718,	val_loss: 0.8439
# 767:	[0s / 36s],		train_loss: 0.8733,	val_loss: 0.8434
# 768:	[0s / 36s],		train_loss: 0.8737,	val_loss: 0.8437
# 769:	[0s / 37s],		train_loss: 0.8708,	val_loss: 0.8419
# 770:	[0s / 37s],		train_loss: 0.8717,	val_loss: 0.8424
# 771:	[0s / 37s],		train_loss: 0.8729,	val_loss: 0.8424
# 772:	[0s / 37s],		train_loss: 0.8702,	val_loss: 0.8425
# 773:	[0s / 37s],		train_loss: 0.8712,	val_loss: 0.8423
# 774:	[0s / 37s],		train_loss: 0.8722,	val_loss: 0.8419
# 775:	[0s / 37s],		train_loss: 0.8693,	val_loss: 0.8425
# 776:	[0s / 37s],		train_loss: 0.8710,	val_loss: 0.8420
# 777:	[0s / 37s],		train_loss: 0.8700,	val_loss: 0.8425
# 778:	[0s / 37s],		train_loss: 0.8697,	val_loss: 0.8424
# 779:	[0s / 37s],		train_loss: 0.8688,	val_loss: 0.8421
# 780:	[0s / 37s],		train_loss: 0.8696,	val_loss: 0.8416
# 781:	[0s / 37s],		train_loss: 0.8723,	val_loss: 0.8414
# 782:	[0s / 37s],		train_loss: 0.8650,	val_loss: 0.8411
# 783:	[0s / 37s],		train_loss: 0.8708,	val_loss: 0.8419
# 784:	[0s / 37s],		train_loss: 0.8705,	val_loss: 0.8430
# 785:	[0s / 37s],		train_loss: 0.8703,	val_loss: 0.8429
# 786:	[0s / 37s],		train_loss: 0.8658,	val_loss: 0.8416
# 787:	[0s / 37s],		train_loss: 0.8648,	val_loss: 0.8421
# 788:	[0s / 37s],		train_loss: 0.8685,	val_loss: 0.8411
# 789:	[0s / 37s],		train_loss: 0.8697,	val_loss: 0.8417
# 790:	[0s / 37s],		train_loss: 0.8686,	val_loss: 0.8417
# 791:	[0s / 37s],		train_loss: 0.8654,	val_loss: 0.8416
# 792:	[0s / 38s],		train_loss: 0.8697,	val_loss: 0.8417
# 793:	[0s / 38s],		train_loss: 0.8673,	val_loss: 0.8415
# 794:	[0s / 38s],		train_loss: 0.8671,	val_loss: 0.8417
# 795:	[0s / 38s],		train_loss: 0.8707,	val_loss: 0.8412
# 796:	[0s / 38s],		train_loss: 0.8686,	val_loss: 0.8410
# 797:	[0s / 38s],		train_loss: 0.8683,	val_loss: 0.8414
# 798:	[0s / 38s],		train_loss: 0.8672,	val_loss: 0.8415
# 799:	[0s / 38s],		train_loss: 0.8690,	val_loss: 0.8407
# 800:	[0s / 38s],		train_loss: 0.8711,	val_loss: 0.8402
# 801:	[0s / 38s],		train_loss: 0.8644,	val_loss: 0.8400
# 802:	[0s / 38s],		train_loss: 0.8657,	val_loss: 0.8412
# 803:	[0s / 38s],		train_loss: 0.8666,	val_loss: 0.8396
# 804:	[0s / 38s],		train_loss: 0.8659,	val_loss: 0.8387
# 805:	[0s / 38s],		train_loss: 0.8658,	val_loss: 0.8402
# 806:	[0s / 38s],		train_loss: 0.8667,	val_loss: 0.8417
# 807:	[0s / 38s],		train_loss: 0.8672,	val_loss: 0.8410
# 808:	[0s / 38s],		train_loss: 0.8651,	val_loss: 0.8398
# 809:	[0s / 38s],		train_loss: 0.8652,	val_loss: 0.8397
# 810:	[0s / 38s],		train_loss: 0.8641,	val_loss: 0.8390
# 811:	[0s / 38s],		train_loss: 0.8647,	val_loss: 0.8392
# 812:	[0s / 38s],		train_loss: 0.8665,	val_loss: 0.8398
# 813:	[0s / 38s],		train_loss: 0.8666,	val_loss: 0.8392
# 814:	[0s / 39s],		train_loss: 0.8653,	val_loss: 0.8388
# 815:	[0s / 39s],		train_loss: 0.8672,	val_loss: 0.8398
# 816:	[0s / 39s],		train_loss: 0.8666,	val_loss: 0.8399
# 817:	[0s / 39s],		train_loss: 0.8659,	val_loss: 0.8394
# 818:	[0s / 39s],		train_loss: 0.8658,	val_loss: 0.8387
# 819:	[0s / 39s],		train_loss: 0.8672,	val_loss: 0.8385
# 820:	[0s / 39s],		train_loss: 0.8638,	val_loss: 0.8393
# 821:	[0s / 39s],		train_loss: 0.8612,	val_loss: 0.8392
# 822:	[0s / 39s],		train_loss: 0.8653,	val_loss: 0.8388
# 823:	[0s / 39s],		train_loss: 0.8647,	val_loss: 0.8389
# 824:	[0s / 39s],		train_loss: 0.8679,	val_loss: 0.8393
# 825:	[0s / 39s],		train_loss: 0.8651,	val_loss: 0.8400
# 826:	[0s / 39s],		train_loss: 0.8657,	val_loss: 0.8400
# 827:	[0s / 39s],		train_loss: 0.8653,	val_loss: 0.8397
# 828:	[0s / 39s],		train_loss: 0.8640,	val_loss: 0.8408
# 829:	[0s / 39s],		train_loss: 0.8649,	val_loss: 0.8392
# 830:	[0s / 39s],		train_loss: 0.8636,	val_loss: 0.8390
# 831:	[0s / 39s],		train_loss: 0.8676,	val_loss: 0.8394
# 832:	[0s / 39s],		train_loss: 0.8656,	val_loss: 0.8400
# 833:	[0s / 39s],		train_loss: 0.8615,	val_loss: 0.8405
# 834:	[0s / 40s],		train_loss: 0.8665,	val_loss: 0.8386
# 835:	[0s / 40s],		train_loss: 0.8647,	val_loss: 0.8392
# 836:	[0s / 40s],		train_loss: 0.8669,	val_loss: 0.8390
# 837:	[0s / 40s],		train_loss: 0.8657,	val_loss: 0.8384
# 838:	[0s / 40s],		train_loss: 0.8673,	val_loss: 0.8386
# 839:	[0s / 40s],		train_loss: 0.8642,	val_loss: 0.8387
# 840:	[0s / 40s],		train_loss: 0.8641,	val_loss: 0.8384
# 841:	[0s / 40s],		train_loss: 0.8652,	val_loss: 0.8380
# 842:	[0s / 40s],		train_loss: 0.8683,	val_loss: 0.8378
# 843:	[0s / 40s],		train_loss: 0.8666,	val_loss: 0.8379
# 844:	[0s / 40s],		train_loss: 0.8639,	val_loss: 0.8380
# 845:	[0s / 40s],		train_loss: 0.8631,	val_loss: 0.8379
# 846:	[0s / 40s],		train_loss: 0.8610,	val_loss: 0.8392
# 847:	[0s / 40s],		train_loss: 0.8642,	val_loss: 0.8378
# 848:	[0s / 40s],		train_loss: 0.8663,	val_loss: 0.8384
# 849:	[0s / 40s],		train_loss: 0.8627,	val_loss: 0.8376
# 850:	[0s / 40s],		train_loss: 0.8641,	val_loss: 0.8378
# 851:	[0s / 40s],		train_loss: 0.8624,	val_loss: 0.8376
# 852:	[0s / 40s],		train_loss: 0.8615,	val_loss: 0.8379
# 853:	[0s / 40s],		train_loss: 0.8639,	val_loss: 0.8380
# 854:	[0s / 40s],		train_loss: 0.8630,	val_loss: 0.8388
# 855:	[0s / 40s],		train_loss: 0.8638,	val_loss: 0.8390
# 856:	[0s / 41s],		train_loss: 0.8609,	val_loss: 0.8392
# 857:	[0s / 41s],		train_loss: 0.8642,	val_loss: 0.8374
# 858:	[0s / 41s],		train_loss: 0.8644,	val_loss: 0.8377
# 859:	[0s / 41s],		train_loss: 0.8619,	val_loss: 0.8361
# 860:	[0s / 41s],		train_loss: 0.8619,	val_loss: 0.8356
# 861:	[0s / 41s],		train_loss: 0.8642,	val_loss: 0.8371
# 862:	[0s / 41s],		train_loss: 0.8626,	val_loss: 0.8367
# 863:	[0s / 41s],		train_loss: 0.8636,	val_loss: 0.8369
# 864:	[0s / 41s],		train_loss: 0.8612,	val_loss: 0.8374
# 865:	[0s / 41s],		train_loss: 0.8632,	val_loss: 0.8368
# 866:	[0s / 41s],		train_loss: 0.8617,	val_loss: 0.8366
# 867:	[0s / 41s],		train_loss: 0.8643,	val_loss: 0.8363
# 868:	[0s / 41s],		train_loss: 0.8640,	val_loss: 0.8367
# 869:	[0s / 41s],		train_loss: 0.8591,	val_loss: 0.8366
# 870:	[0s / 41s],		train_loss: 0.8620,	val_loss: 0.8365
# 871:	[0s / 41s],		train_loss: 0.8589,	val_loss: 0.8378
# 872:	[0s / 41s],		train_loss: 0.8620,	val_loss: 0.8369
# 873:	[0s / 41s],		train_loss: 0.8600,	val_loss: 0.8365
# 874:	[0s / 41s],		train_loss: 0.8594,	val_loss: 0.8354
# 875:	[0s / 41s],		train_loss: 0.8595,	val_loss: 0.8362
# 876:	[0s / 41s],		train_loss: 0.8612,	val_loss: 0.8358
# 877:	[0s / 42s],		train_loss: 0.8573,	val_loss: 0.8353
# ...
# 9729:	[0s / 8m:30s],		train_loss: 0.7246,	val_loss: 0.7701
# 9730:	[0s / 8m:30s],		train_loss: 0.7217,	val_loss: 0.7700
# 9731:	[0s / 8m:30s],		train_loss: 0.7227,	val_loss: 0.7699
# 9732:	[0s / 8m:30s],		train_loss: 0.7225,	val_loss: 0.7700
# 9733:	[0s / 8m:30s],		train_loss: 0.7232,	val_loss: 0.7702
# 9734:	[0s / 8m:30s],		train_loss: 0.7237,	val_loss: 0.7703
# 9735:	[0s / 8m:31s],		train_loss: 0.7241,	val_loss: 0.7700
# 9736:	[0s / 8m:31s],		train_loss: 0.7249,	val_loss: 0.7698
# 9737:	[0s / 8m:31s],		train_loss: 0.7224,	val_loss: 0.7701
# 9738:	[0s / 8m:31s],		train_loss: 0.7219,	val_loss: 0.7703
# 9739:	[0s / 8m:31s],		train_loss: 0.7236,	val_loss: 0.7706
# 9740:	[0s / 8m:31s],		train_loss: 0.7228,	val_loss: 0.7706
# 9741:	[0s / 8m:31s],		train_loss: 0.7232,	val_loss: 0.7699
# 9742:	[0s / 8m:31s],		train_loss: 0.7235,	val_loss: 0.7701
# 9743:	[0s / 8m:31s],		train_loss: 0.7232,	val_loss: 0.7704
# 9744:	[0s / 8m:31s],		train_loss: 0.7247,	val_loss: 0.7703
# 9745:	[0s / 8m:31s],		train_loss: 0.7221,	val_loss: 0.7702
# 9746:	[0s / 8m:31s],		train_loss: 0.7195,	val_loss: 0.7704
# 9747:	[0s / 8m:31s],		train_loss: 0.7238,	val_loss: 0.7709
# 9748:	[0s / 8m:31s],		train_loss: 0.7207,	val_loss: 0.7706
# 9749:	[0s / 8m:31s],		train_loss: 0.7221,	val_loss: 0.7700
# 9750:	[0s / 8m:31s],		train_loss: 0.7249,	val_loss: 0.7699
# 9751:	[0s / 8m:31s],		train_loss: 0.7221,	val_loss: 0.7705
# 9752:	[0s / 8m:32s],		train_loss: 0.7248,	val_loss: 0.7701
# 9753:	[0s / 8m:32s],		train_loss: 0.7209,	val_loss: 0.7701
# 9754:	[0s / 8m:32s],		train_loss: 0.7246,	val_loss: 0.7706
# 9755:	[0s / 8m:32s],		train_loss: 0.7225,	val_loss: 0.7701
# 9756:	[0s / 8m:32s],		train_loss: 0.7248,	val_loss: 0.7699
# 9757:	[0s / 8m:32s],		train_loss: 0.7234,	val_loss: 0.7696
# 9758:	[0s / 8m:32s],		train_loss: 0.7231,	val_loss: 0.7701
# 9759:	[0s / 8m:32s],		train_loss: 0.7223,	val_loss: 0.7700
# 9760:	[0s / 8m:32s],		train_loss: 0.7206,	val_loss: 0.7700
# 9761:	[0s / 8m:32s],		train_loss: 0.7220,	val_loss: 0.7701
# 9762:	[0s / 8m:32s],		train_loss: 0.7202,	val_loss: 0.7699
# 9763:	[0s / 8m:32s],		train_loss: 0.7223,	val_loss: 0.7701
# 9764:	[0s / 8m:32s],		train_loss: 0.7217,	val_loss: 0.7700
# 9765:	[0s / 8m:32s],		train_loss: 0.7239,	val_loss: 0.7704
# 9766:	[0s / 8m:32s],		train_loss: 0.7223,	val_loss: 0.7703
# 9767:	[0s / 8m:32s],		train_loss: 0.7210,	val_loss: 0.7702
# 9768:	[0s / 8m:32s],		train_loss: 0.7219,	val_loss: 0.7701
# 9769:	[0s / 8m:32s],		train_loss: 0.7217,	val_loss: 0.7701
# 9770:	[0s / 8m:33s],		train_loss: 0.7219,	val_loss: 0.7704
# 9771:	[0s / 8m:33s],		train_loss: 0.7226,	val_loss: 0.7702
# 9772:	[0s / 8m:33s],		train_loss: 0.7223,	val_loss: 0.7703
# 9773:	[0s / 8m:33s],		train_loss: 0.7236,	val_loss: 0.7701
# 9774:	[0s / 8m:33s],		train_loss: 0.7229,	val_loss: 0.7702
# 9775:	[0s / 8m:33s],		train_loss: 0.7232,	val_loss: 0.7699
# 9776:	[0s / 8m:33s],		train_loss: 0.7213,	val_loss: 0.7697
# 9777:	[0s / 8m:33s],		train_loss: 0.7220,	val_loss: 0.7700
# 9778:	[0s / 8m:33s],		train_loss: 0.7259,	val_loss: 0.7704
# 9779:	[0s / 8m:33s],		train_loss: 0.7217,	val_loss: 0.7705
# 9780:	[0s / 8m:33s],		train_loss: 0.7250,	val_loss: 0.7701
# 9781:	[0s / 8m:33s],		train_loss: 0.7223,	val_loss: 0.7702
# 9782:	[0s / 8m:33s],		train_loss: 0.7270,	val_loss: 0.7697
# 9783:	[0s / 8m:33s],		train_loss: 0.7236,	val_loss: 0.7699
# 9784:	[0s / 8m:33s],		train_loss: 0.7226,	val_loss: 0.7698
# 9785:	[0s / 8m:33s],		train_loss: 0.7180,	val_loss: 0.7697
# 9786:	[0s / 8m:33s],		train_loss: 0.7253,	val_loss: 0.7699
# 9787:	[0s / 8m:33s],		train_loss: 0.7204,	val_loss: 0.7702
# 9788:	[0s / 8m:34s],		train_loss: 0.7239,	val_loss: 0.7704
# 9789:	[0s / 8m:34s],		train_loss: 0.7222,	val_loss: 0.7700
# 9790:	[0s / 8m:34s],		train_loss: 0.7235,	val_loss: 0.7700
# 9791:	[0s / 8m:34s],		train_loss: 0.7205,	val_loss: 0.7702
# 9792:	[0s / 8m:34s],		train_loss: 0.7220,	val_loss: 0.7701
# 9793:	[0s / 8m:34s],		train_loss: 0.7226,	val_loss: 0.7702
# 9794:	[0s / 8m:34s],		train_loss: 0.7223,	val_loss: 0.7700
# 9795:	[0s / 8m:34s],		train_loss: 0.7239,	val_loss: 0.7700
# 9796:	[0s / 8m:34s],		train_loss: 0.7247,	val_loss: 0.7702
# 9797:	[0s / 8m:34s],		train_loss: 0.7221,	val_loss: 0.7704
# 9798:	[0s / 8m:34s],		train_loss: 0.7226,	val_loss: 0.7704
# 9799:	[0s / 8m:34s],		train_loss: 0.7243,	val_loss: 0.7703
# 9800:	[0s / 8m:34s],		train_loss: 0.7205,	val_loss: 0.7706
# 9801:	[0s / 8m:34s],		train_loss: 0.7188,	val_loss: 0.7705
# 9802:	[0s / 8m:34s],		train_loss: 0.7247,	val_loss: 0.7705
# 9803:	[0s / 8m:34s],		train_loss: 0.7207,	val_loss: 0.7701
# 9804:	[0s / 8m:35s],		train_loss: 0.7246,	val_loss: 0.7701
# 9805:	[0s / 8m:35s],		train_loss: 0.7257,	val_loss: 0.7703
# 9806:	[0s / 8m:35s],		train_loss: 0.7192,	val_loss: 0.7703
# 9807:	[0s / 8m:35s],		train_loss: 0.7210,	val_loss: 0.7703
# 9808:	[0s / 8m:35s],		train_loss: 0.7252,	val_loss: 0.7705
# 9809:	[0s / 8m:35s],		train_loss: 0.7230,	val_loss: 0.7703
# 9810:	[0s / 8m:35s],		train_loss: 0.7225,	val_loss: 0.7704
# 9811:	[0s / 8m:35s],		train_loss: 0.7235,	val_loss: 0.7701
# 9812:	[0s / 8m:35s],		train_loss: 0.7233,	val_loss: 0.7700
# 9813:	[0s / 8m:35s],		train_loss: 0.7220,	val_loss: 0.7705
# 9814:	[0s / 8m:35s],		train_loss: 0.7222,	val_loss: 0.7706
# 9815:	[0s / 8m:35s],		train_loss: 0.7224,	val_loss: 0.7702
# 9816:	[0s / 8m:35s],		train_loss: 0.7226,	val_loss: 0.7703
# 9817:	[0s / 8m:35s],		train_loss: 0.7227,	val_loss: 0.7701
# 9818:	[0s / 8m:35s],		train_loss: 0.7245,	val_loss: 0.7709
# 9819:	[0s / 8m:35s],		train_loss: 0.7238,	val_loss: 0.7705
# 9820:	[0s / 8m:36s],		train_loss: 0.7236,	val_loss: 0.7704
# 9821:	[0s / 8m:36s],		train_loss: 0.7227,	val_loss: 0.7700
# 9822:	[0s / 8m:36s],		train_loss: 0.7235,	val_loss: 0.7700
# 9823:	[0s / 8m:36s],		train_loss: 0.7233,	val_loss: 0.7700
# 9824:	[0s / 8m:36s],		train_loss: 0.7217,	val_loss: 0.7699
# 9825:	[0s / 8m:36s],		train_loss: 0.7234,	val_loss: 0.7702
# 9826:	[0s / 8m:36s],		train_loss: 0.7198,	val_loss: 0.7698
# 9827:	[0s / 8m:36s],		train_loss: 0.7220,	val_loss: 0.7697
# 9828:	[0s / 8m:36s],		train_loss: 0.7229,	val_loss: 0.7702
# 9829:	[0s / 8m:36s],		train_loss: 0.7240,	val_loss: 0.7702
# 9830:	[0s / 8m:36s],		train_loss: 0.7188,	val_loss: 0.7697
# 9831:	[0s / 8m:36s],		train_loss: 0.7232,	val_loss: 0.7700
# 9832:	[0s / 8m:36s],		train_loss: 0.7206,	val_loss: 0.7700
# 9833:	[0s / 8m:36s],		train_loss: 0.7237,	val_loss: 0.7700
# 9834:	[0s / 8m:36s],		train_loss: 0.7219,	val_loss: 0.7702
# 9835:	[0s / 8m:36s],		train_loss: 0.7228,	val_loss: 0.7705
# 9836:	[0s / 8m:37s],		train_loss: 0.7207,	val_loss: 0.7701
# 9837:	[0s / 8m:37s],		train_loss: 0.7220,	val_loss: 0.7702
# 9838:	[0s / 8m:37s],		train_loss: 0.7245,	val_loss: 0.7702
# 9839:	[0s / 8m:37s],		train_loss: 0.7250,	val_loss: 0.7703
# 9840:	[0s / 8m:37s],		train_loss: 0.7241,	val_loss: 0.7706
# 9841:	[0s / 8m:37s],		train_loss: 0.7212,	val_loss: 0.7701
# 9842:	[0s / 8m:37s],		train_loss: 0.7247,	val_loss: 0.7702
# 9843:	[0s / 8m:37s],		train_loss: 0.7183,	val_loss: 0.7696
# 9844:	[0s / 8m:37s],		train_loss: 0.7233,	val_loss: 0.7700
# 9845:	[0s / 8m:37s],		train_loss: 0.7214,	val_loss: 0.7699
# 9846:	[0s / 8m:37s],		train_loss: 0.7240,	val_loss: 0.7698
# 9847:	[0s / 8m:37s],		train_loss: 0.7228,	val_loss: 0.7701
# 9848:	[0s / 8m:37s],		train_loss: 0.7224,	val_loss: 0.7703
# 9849:	[0s / 8m:37s],		train_loss: 0.7224,	val_loss: 0.7700
# 9850:	[0s / 8m:37s],		train_loss: 0.7227,	val_loss: 0.7701
# 9851:	[0s / 8m:37s],		train_loss: 0.7222,	val_loss: 0.7703
# 9852:	[0s / 8m:38s],		train_loss: 0.7211,	val_loss: 0.7707
# 9853:	[0s / 8m:38s],		train_loss: 0.7212,	val_loss: 0.7703
# 9854:	[0s / 8m:38s],		train_loss: 0.7246,	val_loss: 0.7706
# 9855:	[0s / 8m:38s],		train_loss: 0.7247,	val_loss: 0.7702
# 9856:	[0s / 8m:38s],		train_loss: 0.7250,	val_loss: 0.7703
# 9857:	[0s / 8m:38s],		train_loss: 0.7225,	val_loss: 0.7702
# 9858:	[0s / 8m:38s],		train_loss: 0.7238,	val_loss: 0.7699
# 9859:	[0s / 8m:38s],		train_loss: 0.7209,	val_loss: 0.7704
# 9860:	[0s / 8m:38s],		train_loss: 0.7245,	val_loss: 0.7699
# 9861:	[0s / 8m:38s],		train_loss: 0.7227,	val_loss: 0.7699
# 9862:	[0s / 8m:38s],		train_loss: 0.7238,	val_loss: 0.7704
# 9863:	[0s / 8m:38s],		train_loss: 0.7226,	val_loss: 0.7708
# 9864:	[0s / 8m:38s],		train_loss: 0.7218,	val_loss: 0.7707
# 9865:	[0s / 8m:38s],		train_loss: 0.7229,	val_loss: 0.7706
# 9866:	[0s / 8m:38s],		train_loss: 0.7234,	val_loss: 0.7704
# 9867:	[0s / 8m:38s],		train_loss: 0.7237,	val_loss: 0.7701
# 9868:	[0s / 8m:38s],		train_loss: 0.7220,	val_loss: 0.7696
# 9869:	[0s / 8m:39s],		train_loss: 0.7236,	val_loss: 0.7699
# 9870:	[0s / 8m:39s],		train_loss: 0.7215,	val_loss: 0.7703
# 9871:	[0s / 8m:39s],		train_loss: 0.7202,	val_loss: 0.7703
# 9872:	[0s / 8m:39s],		train_loss: 0.7200,	val_loss: 0.7706
# 9873:	[0s / 8m:39s],		train_loss: 0.7221,	val_loss: 0.7702
# 9874:	[0s / 8m:39s],		train_loss: 0.7228,	val_loss: 0.7701
# 9875:	[0s / 8m:39s],		train_loss: 0.7199,	val_loss: 0.7696
# 9876:	[0s / 8m:39s],		train_loss: 0.7238,	val_loss: 0.7696
# 9877:	[0s / 8m:39s],		train_loss: 0.7226,	val_loss: 0.7703
# 9878:	[0s / 8m:39s],		train_loss: 0.7212,	val_loss: 0.7703
# 9879:	[0s / 8m:39s],		train_loss: 0.7229,	val_loss: 0.7703
# 9880:	[0s / 8m:39s],		train_loss: 0.7223,	val_loss: 0.7703
# 9881:	[0s / 8m:39s],		train_loss: 0.7204,	val_loss: 0.7706
# 9882:	[0s / 8m:39s],		train_loss: 0.7200,	val_loss: 0.7700
# 9883:	[0s / 8m:39s],		train_loss: 0.7218,	val_loss: 0.7702
# 9884:	[0s / 8m:39s],		train_loss: 0.7190,	val_loss: 0.7701
# 9885:	[0s / 8m:39s],		train_loss: 0.7222,	val_loss: 0.7702
# 9886:	[0s / 8m:40s],		train_loss: 0.7250,	val_loss: 0.7705
# 9887:	[0s / 8m:40s],		train_loss: 0.7229,	val_loss: 0.7706
# 9888:	[0s / 8m:40s],		train_loss: 0.7255,	val_loss: 0.7708
# 9889:	[0s / 8m:40s],		train_loss: 0.7204,	val_loss: 0.7705
# 9890:	[0s / 8m:40s],		train_loss: 0.7197,	val_loss: 0.7702
# 9891:	[0s / 8m:40s],		train_loss: 0.7185,	val_loss: 0.7701
# 9892:	[0s / 8m:40s],		train_loss: 0.7232,	val_loss: 0.7700
# 9893:	[0s / 8m:40s],		train_loss: 0.7240,	val_loss: 0.7703
# 9894:	[0s / 8m:40s],		train_loss: 0.7207,	val_loss: 0.7705
# 9895:	[0s / 8m:40s],		train_loss: 0.7208,	val_loss: 0.7702
# 9896:	[0s / 8m:40s],		train_loss: 0.7247,	val_loss: 0.7702
# 9897:	[0s / 8m:40s],		train_loss: 0.7215,	val_loss: 0.7706
# 9898:	[0s / 8m:40s],		train_loss: 0.7211,	val_loss: 0.7703
# 9899:	[0s / 8m:40s],		train_loss: 0.7209,	val_loss: 0.7707
# 9900:	[0s / 8m:40s],		train_loss: 0.7236,	val_loss: 0.7705
# 9901:	[0s / 8m:41s],		train_loss: 0.7216,	val_loss: 0.7699
# 9902:	[0s / 8m:41s],		train_loss: 0.7255,	val_loss: 0.7707
# 9903:	[0s / 8m:41s],		train_loss: 0.7276,	val_loss: 0.7700
# 9904:	[0s / 8m:41s],		train_loss: 0.7210,	val_loss: 0.7703
# 9905:	[0s / 8m:41s],		train_loss: 0.7228,	val_loss: 0.7705
# 9906:	[0s / 8m:41s],		train_loss: 0.7219,	val_loss: 0.7700
# 9907:	[0s / 8m:41s],		train_loss: 0.7213,	val_loss: 0.7702
# 9908:	[0s / 8m:41s],		train_loss: 0.7218,	val_loss: 0.7700
# 9909:	[0s / 8m:41s],		train_loss: 0.7218,	val_loss: 0.7699
# 9910:	[0s / 8m:41s],		train_loss: 0.7231,	val_loss: 0.7700
# 9911:	[0s / 8m:41s],		train_loss: 0.7245,	val_loss: 0.7703
# 9912:	[0s / 8m:41s],		train_loss: 0.7214,	val_loss: 0.7704
# 9913:	[0s / 8m:41s],		train_loss: 0.7196,	val_loss: 0.7701
# 9914:	[0s / 8m:41s],		train_loss: 0.7217,	val_loss: 0.7702
# 9915:	[0s / 8m:41s],		train_loss: 0.7209,	val_loss: 0.7703
# 9916:	[0s / 8m:41s],		train_loss: 0.7204,	val_loss: 0.7704
# 9917:	[0s / 8m:42s],		train_loss: 0.7217,	val_loss: 0.7698
# 9918:	[0s / 8m:42s],		train_loss: 0.7244,	val_loss: 0.7705
# 9919:	[0s / 8m:42s],		train_loss: 0.7259,	val_loss: 0.7699
# 9920:	[0s / 8m:42s],		train_loss: 0.7236,	val_loss: 0.7696
# 9921:	[0s / 8m:42s],		train_loss: 0.7218,	val_loss: 0.7698
# 9922:	[0s / 8m:42s],		train_loss: 0.7224,	val_loss: 0.7697
# 9923:	[0s / 8m:42s],		train_loss: 0.7214,	val_loss: 0.7702
# 9924:	[0s / 8m:42s],		train_loss: 0.7231,	val_loss: 0.7699
# 9925:	[0s / 8m:42s],		train_loss: 0.7251,	val_loss: 0.7702
# 9926:	[0s / 8m:42s],		train_loss: 0.7228,	val_loss: 0.7700
# 9927:	[0s / 8m:42s],		train_loss: 0.7221,	val_loss: 0.7697
# 9928:	[0s / 8m:42s],		train_loss: 0.7218,	val_loss: 0.7702
# 9929:	[0s / 8m:42s],		train_loss: 0.7246,	val_loss: 0.7698
# 9930:	[0s / 8m:42s],		train_loss: 0.7208,	val_loss: 0.7700
# 9931:	[0s / 8m:42s],		train_loss: 0.7213,	val_loss: 0.7701
# 9932:	[0s / 8m:42s],		train_loss: 0.7234,	val_loss: 0.7703
# 9933:	[0s / 8m:42s],		train_loss: 0.7237,	val_loss: 0.7703
# 9934:	[0s / 8m:43s],		train_loss: 0.7242,	val_loss: 0.7704
# 9935:	[0s / 8m:43s],		train_loss: 0.7239,	val_loss: 0.7705
# 9936:	[0s / 8m:43s],		train_loss: 0.7218,	val_loss: 0.7703
# 9937:	[0s / 8m:43s],		train_loss: 0.7224,	val_loss: 0.7701
# 9938:	[0s / 8m:43s],		train_loss: 0.7218,	val_loss: 0.7699
# 9939:	[0s / 8m:43s],		train_loss: 0.7219,	val_loss: 0.7700
# 9940:	[0s / 8m:43s],		train_loss: 0.7198,	val_loss: 0.7701
# 9941:	[0s / 8m:43s],		train_loss: 0.7252,	val_loss: 0.7702
# 9942:	[0s / 8m:43s],		train_loss: 0.7213,	val_loss: 0.7699
# 9943:	[0s / 8m:43s],		train_loss: 0.7235,	val_loss: 0.7703
# 9944:	[0s / 8m:43s],		train_loss: 0.7244,	val_loss: 0.7704
# 9945:	[0s / 8m:43s],		train_loss: 0.7198,	val_loss: 0.7702
# 9946:	[0s / 8m:43s],		train_loss: 0.7246,	val_loss: 0.7701
# 9947:	[0s / 8m:43s],		train_loss: 0.7239,	val_loss: 0.7699
# 9948:	[0s / 8m:43s],		train_loss: 0.7194,	val_loss: 0.7703
# 9949:	[0s / 8m:44s],		train_loss: 0.7207,	val_loss: 0.7702
# 9950:	[0s / 8m:44s],		train_loss: 0.7210,	val_loss: 0.7702
# 9951:	[0s / 8m:44s],		train_loss: 0.7240,	val_loss: 0.7705
# 9952:	[0s / 8m:44s],		train_loss: 0.7222,	val_loss: 0.7699
# 9953:	[0s / 8m:44s],		train_loss: 0.7208,	val_loss: 0.7698
# 9954:	[0s / 8m:44s],		train_loss: 0.7242,	val_loss: 0.7702
# 9955:	[0s / 8m:44s],		train_loss: 0.7236,	val_loss: 0.7697
# 9956:	[0s / 8m:44s],		train_loss: 0.7210,	val_loss: 0.7702
# 9957:	[0s / 8m:44s],		train_loss: 0.7222,	val_loss: 0.7702
# 9958:	[0s / 8m:44s],		train_loss: 0.7225,	val_loss: 0.7702
# 9959:	[0s / 8m:44s],		train_loss: 0.7247,	val_loss: 0.7704
# 9960:	[0s / 8m:44s],		train_loss: 0.7205,	val_loss: 0.7704
# 9961:	[0s / 8m:44s],		train_loss: 0.7203,	val_loss: 0.7705
# 9962:	[0s / 8m:44s],		train_loss: 0.7210,	val_loss: 0.7699
# 9963:	[0s / 8m:44s],		train_loss: 0.7225,	val_loss: 0.7703
# 9964:	[0s / 8m:44s],		train_loss: 0.7241,	val_loss: 0.7708
# 9965:	[0s / 8m:45s],		train_loss: 0.7239,	val_loss: 0.7702
# 9966:	[0s / 8m:45s],		train_loss: 0.7249,	val_loss: 0.7699
# 9967:	[0s / 8m:45s],		train_loss: 0.7213,	val_loss: 0.7699
# 9968:	[0s / 8m:45s],		train_loss: 0.7235,	val_loss: 0.7699
# 9969:	[0s / 8m:45s],		train_loss: 0.7240,	val_loss: 0.7700
# 9970:	[0s / 8m:45s],		train_loss: 0.7241,	val_loss: 0.7701
# 9971:	[0s / 8m:45s],		train_loss: 0.7195,	val_loss: 0.7697
# 9972:	[0s / 8m:45s],		train_loss: 0.7206,	val_loss: 0.7700
# 9973:	[0s / 8m:45s],		train_loss: 0.7257,	val_loss: 0.7700
# 9974:	[0s / 8m:45s],		train_loss: 0.7231,	val_loss: 0.7702
# 9975:	[0s / 8m:45s],		train_loss: 0.7222,	val_loss: 0.7705
# 9976:	[0s / 8m:45s],		train_loss: 0.7218,	val_loss: 0.7698
# 9977:	[0s / 8m:45s],		train_loss: 0.7225,	val_loss: 0.7701
# 9978:	[0s / 8m:45s],		train_loss: 0.7220,	val_loss: 0.7694
# 9979:	[0s / 8m:45s],		train_loss: 0.7241,	val_loss: 0.7700
# 9980:	[0s / 8m:45s],		train_loss: 0.7218,	val_loss: 0.7702
# 9981:	[0s / 8m:45s],		train_loss: 0.7214,	val_loss: 0.7701
# 9982:	[0s / 8m:46s],		train_loss: 0.7206,	val_loss: 0.7700
# 9983:	[0s / 8m:46s],		train_loss: 0.7213,	val_loss: 0.7699
# 9984:	[0s / 8m:46s],		train_loss: 0.7217,	val_loss: 0.7704
# 9985:	[0s / 8m:46s],		train_loss: 0.7197,	val_loss: 0.7700
# 9986:	[0s / 8m:46s],		train_loss: 0.7228,	val_loss: 0.7701
# 9987:	[0s / 8m:46s],		train_loss: 0.7228,	val_loss: 0.7705
# 9988:	[0s / 8m:46s],		train_loss: 0.7215,	val_loss: 0.7701
# 9989:	[0s / 8m:46s],		train_loss: 0.7230,	val_loss: 0.7701
# 9990:	[0s / 8m:46s],		train_loss: 0.7242,	val_loss: 0.7705
# 9991:	[0s / 8m:46s],		train_loss: 0.7237,	val_loss: 0.7705
# 9992:	[0s / 8m:46s],		train_loss: 0.7214,	val_loss: 0.7705
# 9993:	[0s / 8m:46s],		train_loss: 0.7200,	val_loss: 0.7703
# 9994:	[0s / 8m:46s],		train_loss: 0.7250,	val_loss: 0.7703
# 9995:	[0s / 8m:46s],		train_loss: 0.7218,	val_loss: 0.7700
# 9996:	[0s / 8m:46s],		train_loss: 0.7204,	val_loss: 0.7700
# 9997:	[0s / 8m:47s],		train_loss: 0.7243,	val_loss: 0.7701
# 9998:	[0s / 8m:47s],		train_loss: 0.7223,	val_loss: 0.7700
# 9999:	[0s / 8m:47s],		train_loss: 0.7218,	val_loss: 0.7701

# %%
# with open(f'model_d{num_durations}_n{"-".join([str(a) for a in num_nodes])}_e{epochs}_lr{lr:.0e}.pkl', 'wb') as handle:
#     pickle.dump(model, handle)

# %%
aggregated_attributions, actual_data_attributions, survshap_attributions, actual_survshap_attributions = compute_attributions(model, x_test, y_test, num_durations, x_raw, all_variables)
aggregated_metric_scores = compute_metrics(model, x_test, y_test, actual_data_attributions, used_metrics)
# Out:
# 100%|██████████| 160/160 [01:16<00:00,  2.08it/s]
# C:\Users\StanislawFrejlak\anaconda3\Lib\site-packages\quantus\helpers\warn.py:262: UserWarning:
#
# The settings for perturbing input e.g., 'perturb_func' didn't cause change in input. Reconsider the parameter settings.

# %%
model.eval()
save_dir = f'./our_plots/exp1_d{num_durations}_n{"-".join([str(a) for a in num_nodes])}_e{epochs}_lr{lr:.0e}'
plot_creator = PlotCreator(save_dir=save_dir)

durations = list(range(num_durations+1))
num_features = x_train.shape[1]

aggregated_attributions_list = [aggregated_attributions[:, :, i] for i in range(aggregated_attributions.shape[-1])]

plot_creator.create_plots(aggregated_attributions_list, all_variables, durations, list(range(4)), desc="IG attributions", save=True)

survshap_attributions_list = [survshap_attributions[:, :, i] for i in range(survshap_attributions.shape[-1])]

plot_creator.create_plots(survshap_attributions_list, all_variables, durations, list(range(4)), desc="SurvSHAP attributions", save=True)

# %%
for ams, m_name in zip(aggregated_metric_scores, metrics_names):
    means, stds = PlotCreator.mean_std_per_time(np.array(ams.squeeze()), y_test[0], num_durations)
    plot_creator.mean_std_figure(ams, m_name, durations, y_means=means, y_stds=stds, desc=f"{m_name} for IG", xaxis_title="Time cuts by label transform", yaxis_title=m_name, legend_title=None, save=True)

# %% [markdown]
# ### Experiment 2: Real-world use case: predicting survival of patients with heart failure

# %% [markdown]
# #### Preparing data and deep model

# %%
# df_raw = pd.read_csv('data/exp3_heart_failure_dataset.csv')
#
# df_train, df_val, df_test = train_val_test_split(df_raw)

# %%
# cols_standardize = ['age', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinine', 'serum_sodium']
# cols_leave = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking']
# num_durations = 50
#
# (train, val, test), labtrans = prepare_x_y([df_train, df_val, df_test], cols_standardize, cols_leave, num_durations, event_column='DEATH_EVENT')
# x_train, y_train = train
# x_val, y_val = val
# x_test, y_test = test

# %% [markdown]
# #### Training deep model

# %%
# in_features = x_train.shape[1]
# num_nodes = [4, 4]
# out_features = labtrans.out_features
# batch_norm = True
# dropout = 0.0
#
# net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm, dropout)
# model = DeepHitSingle(net, tt.optim.Adam(0.0001), duration_index=labtrans.cuts)
#
# batch_size = 64
# epochs = 1000
# callbacks = []# [tt.cb.EarlyStopping()]
#
# log = model.fit(x_train, y_train, batch_size, epochs, callbacks, val_data=val)

# %%
# _ = log.plot()
